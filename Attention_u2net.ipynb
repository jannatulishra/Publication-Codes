# %%
import os
import numpy as np


def load_img(img_dir, img_list):
    images=[]
    for i, image_name in enumerate(img_list):    
        if (image_name.split('.')[1] == 'npy'):
            
            image = np.load(img_dir+image_name)
                      
            images.append(image)
    images = np.array(images)
    
    return(images)




def imageLoader(img_dir, img_list, mask_dir, mask_list, batch_size):

    L = len(img_list)

    #keras needs the generator infinite, so we will use while true  
    while True:

        batch_start = 0
        batch_end = batch_size

        while batch_start < L:
            limit = min(batch_end, L)
                       
            X = load_img(img_dir, img_list[batch_start:limit])
            Y = load_img(mask_dir, mask_list[batch_start:limit])

            # Cast images and masks to float32
            X = X.astype(np.float32)
            Y = Y.astype(np.float32)
            
            yield (X,Y)    

            batch_start += batch_size   
            batch_end += batch_size

# %%
from matplotlib import pyplot as plt
import random

train_img_dir = "Downloads/archive_2/input/output_data/train/images/"
train_mask_dir = "Downloads/archive_2/input/output_data/train/masks/"
train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

# %%
#verfying
img, msk = train_img_datagen.__next__()

# %%
img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

# %%
n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Multiply, Add, UpSampling3D, Activation, Lambda
from keras import backend as K
import tensorflow as tf

kernel_initializer = 'he_uniform'

# Helper function to repeat elements
def repeat_elem(tensor, rep):
    return Lambda(lambda x: K.repeat_elements(x, rep, axis=4))(tensor)

# 3D Gating Signal
def gating_signal_3d(input, out_size, batch_norm=False):
    x = Conv3D(out_size, (1, 1, 1), padding='same')(input)
    if batch_norm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x
def attention_block_3d(x, gating, inter_shape):
    shape_x = K.int_shape(x)

    # No downsampling for theta_x now
    theta_x = Conv3D(inter_shape, (1, 1, 1), padding='same')(x)
    phi_g = Conv3D(inter_shape, (1, 1, 1), padding='same')(gating)

    # Upsample gating to match shape_x directly
    shape_phi_g = K.int_shape(phi_g)
    up_size = tuple(
        max(1, shape_x[i] // shape_phi_g[i]) if shape_phi_g[i] else 1
        for i in range(1, 4)
    )

    upsample_g = UpSampling3D(size=up_size)(phi_g)
    upsample_g = Conv3D(inter_shape, (1, 1, 1), padding='same')(upsample_g)

    concat_xg = Add()([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    psi = Conv3D(1, (1, 1, 1), padding='same')(act_xg)
    sigmoid_xg = Activation('sigmoid')(psi)

    # Resize attention map to x's size
    shape_sigmoid = K.int_shape(sigmoid_xg)
    attn_size = tuple(
        max(1, shape_x[i] // shape_sigmoid[i]) if shape_sigmoid[i] else 1
        for i in range(1, 4)
    )

    sigmoid_xg = UpSampling3D(size=attn_size)(sigmoid_xg)
    attn_coefficients = Multiply()([x, sigmoid_xg])

    return attn_coefficients



# Attention-based concatenation
def attn_concat(x, skip, inter_ch):
    g = gating_signal_3d(x, inter_ch)
    attn = attention_block_3d(skip, g, inter_ch)
    return Concatenate()([x, attn])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, BatchNormalization, Activation, MaxPool3D, UpSampling3D, Concatenate, Add

def conv_block_3d(inputs, out_ch, rate=1):
    x = Conv3D(out_ch, 3, padding="same", dilation_rate=rate)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def RSU_L_3d(inputs, out_ch, int_ch, num_layers, rate=2):
    x = conv_block_3d(inputs, out_ch)
    init_feats = x

    skip = []
    x = conv_block_3d(x, int_ch)
    skip.append(x)

    for i in range(num_layers - 2):
        x = MaxPool3D((2, 2, 2))(x)
        x = conv_block_3d(x, int_ch)
        skip.append(x)

    x = conv_block_3d(x, int_ch, rate=rate)
    skip.reverse()

    x = Concatenate()([x, skip[0]])
    x = conv_block_3d(x, int_ch)

    for i in range(num_layers - 3):
        x = UpSampling3D(size=(2, 2, 2))(x)
        x = Concatenate()([x, skip[i + 1]])
        x = conv_block_3d(x, int_ch)

    x = UpSampling3D(size=(2, 2, 2))(x)
    x = Concatenate()([x, skip[-1]])
    x = conv_block_3d(x, out_ch)

    x = Add()([x, init_feats])
    return x

def RSU_4F_3d(inputs, out_ch, int_ch):
    x0 = conv_block_3d(inputs, out_ch, rate=1)

    x1 = conv_block_3d(x0, int_ch, rate=1)
    x2 = conv_block_3d(x1, int_ch, rate=2)
    x3 = conv_block_3d(x2, int_ch, rate=4)

    x4 = conv_block_3d(x3, int_ch, rate=8)

    x = Concatenate()([x4, x3])
    x = conv_block_3d(x, int_ch, rate=4)

    x = Concatenate()([x, x2])
    x = conv_block_3d(x, int_ch, rate=2)

    x = Concatenate()([x, x1])
    x = conv_block_3d(x, out_ch, rate=1)

    x = Add()([x, x0])
    return x

def u2net_3d_attn(input_shape, out_ch, int_ch, num_classes=1):
    inputs = Input(input_shape)
    s0 = inputs

    s1 = RSU_L_3d(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool3D((2, 2, 2))(s1)

    s2 = RSU_L_3d(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool3D((2, 2, 2))(s2)

    s3 = RSU_L_3d(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool3D((2, 2, 2))(s3)

    s4 = RSU_L_3d(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool3D((2, 2, 2))(s4)

    s5 = RSU_4F_3d(p4, out_ch[4], int_ch[4])
    p5 = MaxPool3D((2, 2, 2))(s5)

    b1 = RSU_4F_3d(p5, out_ch[5], int_ch[5])
    b2 = UpSampling3D(size=(2, 2, 2))(b1)

    d1 = attn_concat(b2, s5, inter_ch=out_ch[4])
    d1 = RSU_4F_3d(d1, out_ch[6], int_ch[6])
    u1 = UpSampling3D(size=(2, 2, 2))(d1)

    d2 = attn_concat(u1, s4, inter_ch=out_ch[3])
    d2 = RSU_L_3d(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling3D(size=(2, 2, 2))(d2)

    d3 = attn_concat(u2, s3, inter_ch=out_ch[2])
    d3 = RSU_L_3d(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling3D(size=(2, 2, 2))(d3)

    d4 = attn_concat(u3, s2, inter_ch=out_ch[1])
    d4 = RSU_L_3d(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling3D(size=(2, 2, 2))(d4)

    d5 = attn_concat(u4, s1, inter_ch=out_ch[0])
    d5 = RSU_L_3d(d5, out_ch[10], int_ch[10], 7)

    """ Side Outputs """
    y1 = Conv3D(num_classes, 3, padding="same")(d5)

    y2 = Conv3D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling3D(size=(2, 2, 2))(y2)

    y3 = Conv3D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling3D(size=(4, 4, 4))(y3)

    y4 = Conv3D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling3D(size=(8, 8, 8))(y4)

    y5 = Conv3D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling3D(size=(16, 16, 16))(y5)
    
    y6 = Conv3D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling3D(size=(32, 32, 32))(y6)

    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv3D(num_classes, 3, padding="same")(y0)

    # Final activation
    y0 = Activation("softmax", name = 'main_output')(y0)
    y1 = Activation("softmax")(y1)
    y2 = Activation("softmax")(y2)
    y3 = Activation("softmax")(y3)
    y4 = Activation("softmax")(y4)
    y5 = Activation("softmax")(y5)
    y6 = Activation("softmax")(y6)

    model = tf.keras.models.Model(inputs, outputs=[y0, y1, y2, y3, y4, y5, y6])
    return model

def build_u2net_3d_attn(input_shape, num_classes=4):
    out_ch = [32, 64, 128, 256, 256, 256, 256, 128, 64, 32, 16]
    int_ch = [16, 16, 32, 64, 128, 128, 128, 64, 32, 16, 8]
    return u2net_3d_attn(input_shape, out_ch, int_ch, num_classes)

# %%
# Input shape: (Depth, Height, Width, Channels)
input_shape = (128, 128, 64, 3)  # Adjust dimensions based on your data

# Number of segmentation classes
num_classes = 4  # BraTS: background, edema, enhancing tumor, non-enhancing tumor

# %%
model = build_u2net_3d_attn(input_shape=input_shape, num_classes=num_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 128, 128, 6  0           []
#                                 4, 3)]
#
#  conv3d_253 (Conv3D)            (None, 128, 128, 64  2624        ['input_5[0][0]']
#                                 , 32)
#
#  batch_normalization_240 (Batch  (None, 128, 128, 64  128        ['conv3d_253[0][0]']
#  Normalization)                 , 32)
#
#  activation_244 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_240[0][0]']
#                                 , 32)
#
#  conv3d_254 (Conv3D)            (None, 128, 128, 64  13840       ['activation_244[0][0]']
#                                 , 16)
#
#  batch_normalization_241 (Batch  (None, 128, 128, 64  64         ['conv3d_254[0][0]']
#  Normalization)                 , 16)
#
#  activation_245 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_241[0][0]']
#                                 , 16)
#
#  max_pooling3d_76 (MaxPooling3D  (None, 64, 64, 32,   0          ['activation_245[0][0]']
#  )                              16)
#
#  conv3d_255 (Conv3D)            (None, 64, 64, 32,   6928        ['max_pooling3d_76[0][0]']
#                                 16)
#
#  batch_normalization_242 (Batch  (None, 64, 64, 32,   64         ['conv3d_255[0][0]']
#  Normalization)                 16)
#
#  activation_246 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_242[0][0]']
#                                 16)
#
#  max_pooling3d_77 (MaxPooling3D  (None, 32, 32, 16,   0          ['activation_246[0][0]']
#  )                              16)
#
#  conv3d_256 (Conv3D)            (None, 32, 32, 16,   6928        ['max_pooling3d_77[0][0]']
#                                 16)
#
#  batch_normalization_243 (Batch  (None, 32, 32, 16,   64         ['conv3d_256[0][0]']
#  Normalization)                 16)
#
#  activation_247 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_243[0][0]']
#                                 16)
#
#  max_pooling3d_78 (MaxPooling3D  (None, 16, 16, 8, 1  0          ['activation_247[0][0]']
#  )                              6)
#
#  conv3d_257 (Conv3D)            (None, 16, 16, 8, 1  6928        ['max_pooling3d_78[0][0]']
#                                 6)
#
#  batch_normalization_244 (Batch  (None, 16, 16, 8, 1  64         ['conv3d_257[0][0]']
#  Normalization)                 6)
#
#  activation_248 (Activation)    (None, 16, 16, 8, 1  0           ['batch_normalization_244[0][0]']
#                                 6)
#
#  max_pooling3d_79 (MaxPooling3D  (None, 8, 8, 4, 16)  0          ['activation_248[0][0]']
#  )
#
#  conv3d_258 (Conv3D)            (None, 8, 8, 4, 16)  6928        ['max_pooling3d_79[0][0]']
#
#  batch_normalization_245 (Batch  (None, 8, 8, 4, 16)  64         ['conv3d_258[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 8, 8, 4, 16)  0           ['batch_normalization_245[0][0]']
#
#  max_pooling3d_80 (MaxPooling3D  (None, 4, 4, 2, 16)  0          ['activation_249[0][0]']
#  )
#
#  conv3d_259 (Conv3D)            (None, 4, 4, 2, 16)  6928        ['max_pooling3d_80[0][0]']
#
#  batch_normalization_246 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_259[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_246[0][0]']
#
#  conv3d_260 (Conv3D)            (None, 4, 4, 2, 16)  6928        ['activation_250[0][0]']
#
#  batch_normalization_247 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_260[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_247[0][0]']
#
#  concatenate_96 (Concatenate)   (None, 4, 4, 2, 32)  0           ['activation_251[0][0]',
#                                                                   'activation_250[0][0]']
#
#  conv3d_261 (Conv3D)            (None, 4, 4, 2, 16)  13840       ['concatenate_96[0][0]']
#
#  batch_normalization_248 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_261[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_248[0][0]']
#
#  up_sampling3d_61 (UpSampling3D  (None, 8, 8, 4, 16)  0          ['activation_252[0][0]']
#  )
#
#  concatenate_97 (Concatenate)   (None, 8, 8, 4, 32)  0           ['up_sampling3d_61[0][0]',
#                                                                   'activation_249[0][0]']
#
#  conv3d_262 (Conv3D)            (None, 8, 8, 4, 16)  13840       ['concatenate_97[0][0]']
#
#  batch_normalization_249 (Batch  (None, 8, 8, 4, 16)  64         ['conv3d_262[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 8, 8, 4, 16)  0           ['batch_normalization_249[0][0]']
#
#  up_sampling3d_62 (UpSampling3D  (None, 16, 16, 8, 1  0          ['activation_253[0][0]']
#  )                              6)
#
#  concatenate_98 (Concatenate)   (None, 16, 16, 8, 3  0           ['up_sampling3d_62[0][0]',
#                                 2)                                'activation_248[0][0]']
#
#  conv3d_263 (Conv3D)            (None, 16, 16, 8, 1  13840       ['concatenate_98[0][0]']
#                                 6)
#
#  batch_normalization_250 (Batch  (None, 16, 16, 8, 1  64         ['conv3d_263[0][0]']
#  Normalization)                 6)
#
#  activation_254 (Activation)    (None, 16, 16, 8, 1  0           ['batch_normalization_250[0][0]']
#                                 6)
#
#  up_sampling3d_63 (UpSampling3D  (None, 32, 32, 16,   0          ['activation_254[0][0]']
#  )                              16)
#
#  concatenate_99 (Concatenate)   (None, 32, 32, 16,   0           ['up_sampling3d_63[0][0]',
#                                 32)                               'activation_247[0][0]']
#
#  conv3d_264 (Conv3D)            (None, 32, 32, 16,   13840       ['concatenate_99[0][0]']
#                                 16)
#
#  batch_normalization_251 (Batch  (None, 32, 32, 16,   64         ['conv3d_264[0][0]']
#  Normalization)                 16)
#
#  activation_255 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_251[0][0]']
#                                 16)
#
#  up_sampling3d_64 (UpSampling3D  (None, 64, 64, 32,   0          ['activation_255[0][0]']
#  )                              16)
#
#  concatenate_100 (Concatenate)  (None, 64, 64, 32,   0           ['up_sampling3d_64[0][0]',
#                                 32)                               'activation_246[0][0]']
#
#  conv3d_265 (Conv3D)            (None, 64, 64, 32,   13840       ['concatenate_100[0][0]']
#                                 16)
#
#  batch_normalization_252 (Batch  (None, 64, 64, 32,   64         ['conv3d_265[0][0]']
#  Normalization)                 16)
#
#  activation_256 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_252[0][0]']
#                                 16)
#
#  up_sampling3d_65 (UpSampling3D  (None, 128, 128, 64  0          ['activation_256[0][0]']
#  )                              , 16)
#
#  concatenate_101 (Concatenate)  (None, 128, 128, 64  0           ['up_sampling3d_65[0][0]',
#                                 , 32)                             'activation_245[0][0]']
#
#  conv3d_266 (Conv3D)            (None, 128, 128, 64  27680       ['concatenate_101[0][0]']
#                                 , 32)
#
#  batch_normalization_253 (Batch  (None, 128, 128, 64  128        ['conv3d_266[0][0]']
#  Normalization)                 , 32)
#
#  activation_257 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_253[0][0]']
#                                 , 32)
#
#  add_26 (Add)                   (None, 128, 128, 64  0           ['activation_257[0][0]',
#                                 , 32)                             'activation_244[0][0]']
#
#  max_pooling3d_81 (MaxPooling3D  (None, 64, 64, 32,   0          ['add_26[0][0]']
#  )                              32)
#
#  conv3d_267 (Conv3D)            (None, 64, 64, 32,   55360       ['max_pooling3d_81[0][0]']
#                                 64)
#
#  batch_normalization_254 (Batch  (None, 64, 64, 32,   256        ['conv3d_267[0][0]']
#  Normalization)                 64)
#
#  activation_258 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_254[0][0]']
#                                 64)
#
#  conv3d_268 (Conv3D)            (None, 64, 64, 32,   27664       ['activation_258[0][0]']
#                                 16)
#
#  batch_normalization_255 (Batch  (None, 64, 64, 32,   64         ['conv3d_268[0][0]']
#  Normalization)                 16)
#
#  activation_259 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_255[0][0]']
#                                 16)
#
#  max_pooling3d_82 (MaxPooling3D  (None, 32, 32, 16,   0          ['activation_259[0][0]']
#  )                              16)
#
#  conv3d_269 (Conv3D)            (None, 32, 32, 16,   6928        ['max_pooling3d_82[0][0]']
#                                 16)
#
#  batch_normalization_256 (Batch  (None, 32, 32, 16,   64         ['conv3d_269[0][0]']
#  Normalization)                 16)
#
#  activation_260 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_256[0][0]']
#                                 16)
#
#  max_pooling3d_83 (MaxPooling3D  (None, 16, 16, 8, 1  0          ['activation_260[0][0]']
#  )                              6)
#
#  conv3d_270 (Conv3D)            (None, 16, 16, 8, 1  6928        ['max_pooling3d_83[0][0]']
#                                 6)
#
#  batch_normalization_257 (Batch  (None, 16, 16, 8, 1  64         ['conv3d_270[0][0]']
#  Normalization)                 6)
#
#  activation_261 (Activation)    (None, 16, 16, 8, 1  0           ['batch_normalization_257[0][0]']
#                                 6)
#
#  max_pooling3d_84 (MaxPooling3D  (None, 8, 8, 4, 16)  0          ['activation_261[0][0]']
#  )
#
#  conv3d_271 (Conv3D)            (None, 8, 8, 4, 16)  6928        ['max_pooling3d_84[0][0]']
#
#  batch_normalization_258 (Batch  (None, 8, 8, 4, 16)  64         ['conv3d_271[0][0]']
#  Normalization)
#
#  activation_262 (Activation)    (None, 8, 8, 4, 16)  0           ['batch_normalization_258[0][0]']
#
#  max_pooling3d_85 (MaxPooling3D  (None, 4, 4, 2, 16)  0          ['activation_262[0][0]']
#  )
#
#  conv3d_272 (Conv3D)            (None, 4, 4, 2, 16)  6928        ['max_pooling3d_85[0][0]']
#
#  batch_normalization_259 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_272[0][0]']
#  Normalization)
#
#  activation_263 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_259[0][0]']
#
#  conv3d_273 (Conv3D)            (None, 4, 4, 2, 16)  6928        ['activation_263[0][0]']
#
#  batch_normalization_260 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_273[0][0]']
#  Normalization)
#
#  activation_264 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_260[0][0]']
#
#  concatenate_102 (Concatenate)  (None, 4, 4, 2, 32)  0           ['activation_264[0][0]',
#                                                                   'activation_263[0][0]']
#
#  conv3d_274 (Conv3D)            (None, 4, 4, 2, 16)  13840       ['concatenate_102[0][0]']
#
#  batch_normalization_261 (Batch  (None, 4, 4, 2, 16)  64         ['conv3d_274[0][0]']
#  Normalization)
#
#  activation_265 (Activation)    (None, 4, 4, 2, 16)  0           ['batch_normalization_261[0][0]']
#
#  up_sampling3d_66 (UpSampling3D  (None, 8, 8, 4, 16)  0          ['activation_265[0][0]']
#  )
#
#  concatenate_103 (Concatenate)  (None, 8, 8, 4, 32)  0           ['up_sampling3d_66[0][0]',
#                                                                   'activation_262[0][0]']
#
#  conv3d_275 (Conv3D)            (None, 8, 8, 4, 16)  13840       ['concatenate_103[0][0]']
#
#  batch_normalization_262 (Batch  (None, 8, 8, 4, 16)  64         ['conv3d_275[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 8, 8, 4, 16)  0           ['batch_normalization_262[0][0]']
#
#  up_sampling3d_67 (UpSampling3D  (None, 16, 16, 8, 1  0          ['activation_266[0][0]']
#  )                              6)
#
#  concatenate_104 (Concatenate)  (None, 16, 16, 8, 3  0           ['up_sampling3d_67[0][0]',
#                                 2)                                'activation_261[0][0]']
#
#  conv3d_276 (Conv3D)            (None, 16, 16, 8, 1  13840       ['concatenate_104[0][0]']
#                                 6)
#
#  batch_normalization_263 (Batch  (None, 16, 16, 8, 1  64         ['conv3d_276[0][0]']
#  Normalization)                 6)
#
#  activation_267 (Activation)    (None, 16, 16, 8, 1  0           ['batch_normalization_263[0][0]']
#                                 6)
#
#  up_sampling3d_68 (UpSampling3D  (None, 32, 32, 16,   0          ['activation_267[0][0]']
#  )                              16)
#
#  concatenate_105 (Concatenate)  (None, 32, 32, 16,   0           ['up_sampling3d_68[0][0]',
#                                 32)                               'activation_260[0][0]']
#
#  conv3d_277 (Conv3D)            (None, 32, 32, 16,   13840       ['concatenate_105[0][0]']
#                                 16)
#
#  batch_normalization_264 (Batch  (None, 32, 32, 16,   64         ['conv3d_277[0][0]']
#  Normalization)                 16)
#
#  activation_268 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_264[0][0]']
#                                 16)
#
#  up_sampling3d_69 (UpSampling3D  (None, 64, 64, 32,   0          ['activation_268[0][0]']
#  )                              16)
#
#  concatenate_106 (Concatenate)  (None, 64, 64, 32,   0           ['up_sampling3d_69[0][0]',
#                                 32)                               'activation_259[0][0]']
#
#  conv3d_278 (Conv3D)            (None, 64, 64, 32,   55360       ['concatenate_106[0][0]']
#                                 64)
#
#  batch_normalization_265 (Batch  (None, 64, 64, 32,   256        ['conv3d_278[0][0]']
#  Normalization)                 64)
#
#  activation_269 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_265[0][0]']
#                                 64)
#
#  add_27 (Add)                   (None, 64, 64, 32,   0           ['activation_269[0][0]',
#                                 64)                               'activation_258[0][0]']
#
#  max_pooling3d_86 (MaxPooling3D  (None, 32, 32, 16,   0          ['add_27[0][0]']
#  )                              64)
#
#  conv3d_279 (Conv3D)            (None, 32, 32, 16,   221312      ['max_pooling3d_86[0][0]']
#                                 128)
#
#  batch_normalization_266 (Batch  (None, 32, 32, 16,   512        ['conv3d_279[0][0]']
#  Normalization)                 128)
#
#  activation_270 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_266[0][0]']
#                                 128)
#
#  conv3d_280 (Conv3D)            (None, 32, 32, 16,   110624      ['activation_270[0][0]']
#                                 32)
#
#  batch_normalization_267 (Batch  (None, 32, 32, 16,   128        ['conv3d_280[0][0]']
#  Normalization)                 32)
#
#  activation_271 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_267[0][0]']
#                                 32)
#
#  max_pooling3d_87 (MaxPooling3D  (None, 16, 16, 8, 3  0          ['activation_271[0][0]']
#  )                              2)
#
#  conv3d_281 (Conv3D)            (None, 16, 16, 8, 3  27680       ['max_pooling3d_87[0][0]']
#                                 2)
#
#  batch_normalization_268 (Batch  (None, 16, 16, 8, 3  128        ['conv3d_281[0][0]']
#  Normalization)                 2)
#
#  activation_272 (Activation)    (None, 16, 16, 8, 3  0           ['batch_normalization_268[0][0]']
#                                 2)
#
#  max_pooling3d_88 (MaxPooling3D  (None, 8, 8, 4, 32)  0          ['activation_272[0][0]']
#  )
#
#  conv3d_282 (Conv3D)            (None, 8, 8, 4, 32)  27680       ['max_pooling3d_88[0][0]']
#
#  batch_normalization_269 (Batch  (None, 8, 8, 4, 32)  128        ['conv3d_282[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 8, 8, 4, 32)  0           ['batch_normalization_269[0][0]']
#
#  max_pooling3d_89 (MaxPooling3D  (None, 4, 4, 2, 32)  0          ['activation_273[0][0]']
#  )
#
#  conv3d_283 (Conv3D)            (None, 4, 4, 2, 32)  27680       ['max_pooling3d_89[0][0]']
#
#  batch_normalization_270 (Batch  (None, 4, 4, 2, 32)  128        ['conv3d_283[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 4, 4, 2, 32)  0           ['batch_normalization_270[0][0]']
#
#  conv3d_284 (Conv3D)            (None, 4, 4, 2, 32)  27680       ['activation_274[0][0]']
#
#  batch_normalization_271 (Batch  (None, 4, 4, 2, 32)  128        ['conv3d_284[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 4, 4, 2, 32)  0           ['batch_normalization_271[0][0]']
#
#  concatenate_107 (Concatenate)  (None, 4, 4, 2, 64)  0           ['activation_275[0][0]',
#                                                                   'activation_274[0][0]']
#
#  conv3d_285 (Conv3D)            (None, 4, 4, 2, 32)  55328       ['concatenate_107[0][0]']
#
#  batch_normalization_272 (Batch  (None, 4, 4, 2, 32)  128        ['conv3d_285[0][0]']
#  Normalization)
#
#  activation_276 (Activation)    (None, 4, 4, 2, 32)  0           ['batch_normalization_272[0][0]']
#
#  up_sampling3d_70 (UpSampling3D  (None, 8, 8, 4, 32)  0          ['activation_276[0][0]']
#  )
#
#  concatenate_108 (Concatenate)  (None, 8, 8, 4, 64)  0           ['up_sampling3d_70[0][0]',
#                                                                   'activation_273[0][0]']
#
#  conv3d_286 (Conv3D)            (None, 8, 8, 4, 32)  55328       ['concatenate_108[0][0]']
#
#  batch_normalization_273 (Batch  (None, 8, 8, 4, 32)  128        ['conv3d_286[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 8, 8, 4, 32)  0           ['batch_normalization_273[0][0]']
#
#  up_sampling3d_71 (UpSampling3D  (None, 16, 16, 8, 3  0          ['activation_277[0][0]']
#  )                              2)
#
#  concatenate_109 (Concatenate)  (None, 16, 16, 8, 6  0           ['up_sampling3d_71[0][0]',
#                                 4)                                'activation_272[0][0]']
#
#  conv3d_287 (Conv3D)            (None, 16, 16, 8, 3  55328       ['concatenate_109[0][0]']
#                                 2)
#
#  batch_normalization_274 (Batch  (None, 16, 16, 8, 3  128        ['conv3d_287[0][0]']
#  Normalization)                 2)
#
#  activation_278 (Activation)    (None, 16, 16, 8, 3  0           ['batch_normalization_274[0][0]']
#                                 2)
#
#  up_sampling3d_72 (UpSampling3D  (None, 32, 32, 16,   0          ['activation_278[0][0]']
#  )                              32)
#
#  concatenate_110 (Concatenate)  (None, 32, 32, 16,   0           ['up_sampling3d_72[0][0]',
#                                 64)                               'activation_271[0][0]']
#
#  conv3d_288 (Conv3D)            (None, 32, 32, 16,   221312      ['concatenate_110[0][0]']
#                                 128)
#
#  batch_normalization_275 (Batch  (None, 32, 32, 16,   512        ['conv3d_288[0][0]']
#  Normalization)                 128)
#
#  activation_279 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_275[0][0]']
#                                 128)
#
#  add_28 (Add)                   (None, 32, 32, 16,   0           ['activation_279[0][0]',
#                                 128)                              'activation_270[0][0]']
#
#  max_pooling3d_90 (MaxPooling3D  (None, 16, 16, 8, 1  0          ['add_28[0][0]']
#  )                              28)
#
#  conv3d_289 (Conv3D)            (None, 16, 16, 8, 2  884992      ['max_pooling3d_90[0][0]']
#                                 56)
#
#  batch_normalization_276 (Batch  (None, 16, 16, 8, 2  1024       ['conv3d_289[0][0]']
#  Normalization)                 56)
#
#  activation_280 (Activation)    (None, 16, 16, 8, 2  0           ['batch_normalization_276[0][0]']
#                                 56)
#
#  conv3d_290 (Conv3D)            (None, 16, 16, 8, 6  442432      ['activation_280[0][0]']
#                                 4)
#
#  batch_normalization_277 (Batch  (None, 16, 16, 8, 6  256        ['conv3d_290[0][0]']
#  Normalization)                 4)
#
#  activation_281 (Activation)    (None, 16, 16, 8, 6  0           ['batch_normalization_277[0][0]']
#                                 4)
#
#  max_pooling3d_91 (MaxPooling3D  (None, 8, 8, 4, 64)  0          ['activation_281[0][0]']
#  )
#
#  conv3d_291 (Conv3D)            (None, 8, 8, 4, 64)  110656      ['max_pooling3d_91[0][0]']
#
#  batch_normalization_278 (Batch  (None, 8, 8, 4, 64)  256        ['conv3d_291[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 8, 8, 4, 64)  0           ['batch_normalization_278[0][0]']
#
#  max_pooling3d_92 (MaxPooling3D  (None, 4, 4, 2, 64)  0          ['activation_282[0][0]']
#  )
#
#  conv3d_292 (Conv3D)            (None, 4, 4, 2, 64)  110656      ['max_pooling3d_92[0][0]']
#
#  batch_normalization_279 (Batch  (None, 4, 4, 2, 64)  256        ['conv3d_292[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 4, 4, 2, 64)  0           ['batch_normalization_279[0][0]']
#
#  conv3d_293 (Conv3D)            (None, 4, 4, 2, 64)  110656      ['activation_283[0][0]']
#
#  batch_normalization_280 (Batch  (None, 4, 4, 2, 64)  256        ['conv3d_293[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 4, 4, 2, 64)  0           ['batch_normalization_280[0][0]']
#
#  concatenate_111 (Concatenate)  (None, 4, 4, 2, 128  0           ['activation_284[0][0]',
#                                 )                                 'activation_283[0][0]']
#
#  conv3d_294 (Conv3D)            (None, 4, 4, 2, 64)  221248      ['concatenate_111[0][0]']
# ...
#
#  activation_363 (Activation)    (None, 4, 4, 2, 8)   0           ['batch_normalization_344[0][0]']
#
#  conv3d_383 (Conv3D)            (None, 4, 4, 2, 8)   1736        ['activation_363[0][0]']
#
#  batch_normalization_345 (Batch  (None, 4, 4, 2, 8)  32          ['conv3d_383[0][0]']
#  Normalization)
#
#  activation_364 (Activation)    (None, 4, 4, 2, 8)   0           ['batch_normalization_345[0][0]']
#
#  concatenate_140 (Concatenate)  (None, 4, 4, 2, 16)  0           ['activation_364[0][0]',
#                                                                   'activation_363[0][0]']
#
#  conv3d_384 (Conv3D)            (None, 4, 4, 2, 8)   3464        ['concatenate_140[0][0]']
#
#  batch_normalization_346 (Batch  (None, 4, 4, 2, 8)  32          ['conv3d_384[0][0]']
#  Normalization)
#
#  activation_365 (Activation)    (None, 4, 4, 2, 8)   0           ['batch_normalization_346[0][0]']
#
#  up_sampling3d_99 (UpSampling3D  (None, 8, 8, 4, 8)  0           ['activation_365[0][0]']
#  )
#
#  concatenate_141 (Concatenate)  (None, 8, 8, 4, 16)  0           ['up_sampling3d_99[0][0]',
#                                                                   'activation_362[0][0]']
#
#  conv3d_385 (Conv3D)            (None, 8, 8, 4, 8)   3464        ['concatenate_141[0][0]']
#
#  batch_normalization_347 (Batch  (None, 8, 8, 4, 8)  32          ['conv3d_385[0][0]']
#  Normalization)
#
#  activation_366 (Activation)    (None, 8, 8, 4, 8)   0           ['batch_normalization_347[0][0]']
#
#  up_sampling3d_100 (UpSampling3  (None, 16, 16, 8, 8  0          ['activation_366[0][0]']
#  D)                             )
#
#  concatenate_142 (Concatenate)  (None, 16, 16, 8, 1  0           ['up_sampling3d_100[0][0]',
#                                 6)                                'activation_361[0][0]']
#
#  conv3d_386 (Conv3D)            (None, 16, 16, 8, 8  3464        ['concatenate_142[0][0]']
#                                 )
#
#  batch_normalization_348 (Batch  (None, 16, 16, 8, 8  32         ['conv3d_386[0][0]']
#  Normalization)                 )
#
#  activation_367 (Activation)    (None, 16, 16, 8, 8  0           ['batch_normalization_348[0][0]']
#                                 )
#
#  up_sampling3d_101 (UpSampling3  (None, 32, 32, 16,   0          ['activation_367[0][0]']
#  D)                             8)
#
#  concatenate_143 (Concatenate)  (None, 32, 32, 16,   0           ['up_sampling3d_101[0][0]',
#                                 16)                               'activation_360[0][0]']
#
#  conv3d_387 (Conv3D)            (None, 32, 32, 16,   3464        ['concatenate_143[0][0]']
#                                 8)
#
#  batch_normalization_349 (Batch  (None, 32, 32, 16,   32         ['conv3d_387[0][0]']
#  Normalization)                 8)
#
#  activation_368 (Activation)    (None, 32, 32, 16,   0           ['batch_normalization_349[0][0]']
#                                 8)
#
#  up_sampling3d_102 (UpSampling3  (None, 64, 64, 32,   0          ['activation_368[0][0]']
#  D)                             8)
#
#  concatenate_144 (Concatenate)  (None, 64, 64, 32,   0           ['up_sampling3d_102[0][0]',
#                                 16)                               'activation_359[0][0]']
#
#  conv3d_388 (Conv3D)            (None, 64, 64, 32,   3464        ['concatenate_144[0][0]']
#                                 8)
#
#  batch_normalization_350 (Batch  (None, 64, 64, 32,   32         ['conv3d_388[0][0]']
#  Normalization)                 8)
#
#  activation_369 (Activation)    (None, 64, 64, 32,   0           ['batch_normalization_350[0][0]']
#                                 8)
#
#  up_sampling3d_103 (UpSampling3  (None, 128, 128, 64  0          ['activation_369[0][0]']
#  D)                             , 8)
#
#  concatenate_145 (Concatenate)  (None, 128, 128, 64  0           ['up_sampling3d_103[0][0]',
#                                 , 16)                             'activation_358[0][0]']
#
#  conv3d_389 (Conv3D)            (None, 128, 128, 64  6928        ['concatenate_145[0][0]']
#                                 , 16)
#
#  batch_normalization_351 (Batch  (None, 128, 128, 64  64         ['conv3d_389[0][0]']
#  Normalization)                 , 16)
#
#  activation_370 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_351[0][0]']
#                                 , 16)
#
#  add_41 (Add)                   (None, 128, 128, 64  0           ['activation_370[0][0]',
#                                 , 16)                             'activation_357[0][0]']
#
#  conv3d_391 (Conv3D)            (None, 64, 64, 32,   3460        ['add_39[0][0]']
#                                 4)
#
#  conv3d_392 (Conv3D)            (None, 32, 32, 16,   6916        ['add_37[0][0]']
#                                 4)
#
#  conv3d_393 (Conv3D)            (None, 16, 16, 8, 4  13828       ['add_35[0][0]']
#                                 )
#
#  conv3d_394 (Conv3D)            (None, 8, 8, 4, 4)   27652       ['add_33[0][0]']
#
#  conv3d_395 (Conv3D)            (None, 4, 4, 2, 4)   27652       ['add_31[0][0]']
#
#  conv3d_390 (Conv3D)            (None, 128, 128, 64  1732        ['add_41[0][0]']
#                                 , 4)
#
#  up_sampling3d_104 (UpSampling3  (None, 128, 128, 64  0          ['conv3d_391[0][0]']
#  D)                             , 4)
#
#  up_sampling3d_105 (UpSampling3  (None, 128, 128, 64  0          ['conv3d_392[0][0]']
#  D)                             , 4)
#
#  up_sampling3d_106 (UpSampling3  (None, 128, 128, 64  0          ['conv3d_393[0][0]']
#  D)                             , 4)
#
#  up_sampling3d_107 (UpSampling3  (None, 128, 128, 64  0          ['conv3d_394[0][0]']
#  D)                             , 4)
#
#  up_sampling3d_108 (UpSampling3  (None, 128, 128, 64  0          ['conv3d_395[0][0]']
#  D)                             , 4)
#
#  concatenate_146 (Concatenate)  (None, 128, 128, 64  0           ['conv3d_390[0][0]',
#                                 , 24)                             'up_sampling3d_104[0][0]',
#                                                                   'up_sampling3d_105[0][0]',
#                                                                   'up_sampling3d_106[0][0]',
#                                                                   'up_sampling3d_107[0][0]',
#                                                                   'up_sampling3d_108[0][0]']
#
#  conv3d_396 (Conv3D)            (None, 128, 128, 64  2596        ['concatenate_146[0][0]']
#                                 , 4)
#
#  main_output (Activation)       (None, 128, 128, 64  0           ['conv3d_396[0][0]']
#                                 , 4)
#
#  activation_371 (Activation)    (None, 128, 128, 64  0           ['conv3d_390[0][0]']
#                                 , 4)
#
#  activation_372 (Activation)    (None, 128, 128, 64  0           ['up_sampling3d_104[0][0]']
#                                 , 4)
#
#  activation_373 (Activation)    (None, 128, 128, 64  0           ['up_sampling3d_105[0][0]']
#                                 , 4)
#
#  activation_374 (Activation)    (None, 128, 128, 64  0           ['up_sampling3d_106[0][0]']
#                                 , 4)
#
#  activation_375 (Activation)    (None, 128, 128, 64  0           ['up_sampling3d_107[0][0]']
#                                 , 4)
#
#  activation_376 (Activation)    (None, 128, 128, 64  0           ['up_sampling3d_108[0][0]']
#                                 , 4)
#
# ==================================================================================================
# Total params: 33,661,569
# Trainable params: 33,647,233
# Non-trainable params: 14,336
# __________________________________________________________________________________________________

# %%
import os
import numpy as np
import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random

# %%
train_img_dir = "Downloads/archive_2/input/output_data/train/images/"
train_mask_dir = "Downloads/archive_2/input/output_data/train/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))
img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

# %%
n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
#Define the image generators for training and validation

train_img_dir = "Downloads/archive_2/input/output_data/train/images/"
train_mask_dir = "Downloads/archive_2/input/output_data/train/masks/"

val_img_dir = "Downloads/archive_2/input/output_data/val/images/"
val_mask_dir = "Downloads/archive_2/input/output_data/val/masks/"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

# %%
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    """
    Dice coefficient for multi-class segmentation.
    y_true: Ground truth (batch_size, height, width, num_classes)
    y_pred: Predicted probabilities (batch_size, height, width, num_classes)
    smooth: Smoothing factor to avoid division by zero.
    """
    class_num = 4  # Fixed number of classes
    total_loss = 0.0

    for i in range(class_num):
        y_true_f = K.flatten(y_true[..., i])  # Flatten the ground truth for class i
        y_pred_f = K.flatten(y_pred[..., i])  # Flatten the predictions for class i
        intersection = K.sum(y_true_f * y_pred_f)  # Compute the intersection
        loss = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
        total_loss += loss

    return total_loss / class_num  # Return the average Dice coefficient

# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
#wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
#
#dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
#focal_loss = sm.losses.CategoricalFocalLoss()
#total_loss = dice_loss + (1 * focal_loss)

#import tensorflow as tf
#from tensorflow.keras import backend as K

#def focal_loss(gamma=2.0, alpha=0.25):
#    def focal_loss_fn(y_true, y_pred):
        # Clip predictions to prevent log(0) or log(1)
#        y_pred = K.clip(y_pred, K.epsilon(), 1.0 - K.epsilon())
        
        # Calculate cross-entropy
#        cross_entropy = -y_true * K.log(y_pred)
        
        # Calculate the focal loss
#        loss = alpha * K.pow(1.0 - y_pred, gamma) * cross_entropy
        
        # Sum over classes and average over batch
#        return K.sum(loss, axis=-1)
    
#   return focal_loss_fn

metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity]

LR = 0.0001
optim = keras.optimizers.Adam(LR)

# %%
#Fit the model 
#import segmentation_models_3D as sm
steps_per_epoch = len(train_img_list)//batch_size
val_steps_per_epoch = len(val_img_list)//batch_size

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "Downloads/archive_2/model_segmentation/u2net_3d__attn_200epoch.hdf5",  # Save path
    monitor="val_main_output_dice_coef",  # Monitor validation dice coefficient
    save_best_only=True,  # Save only the best model
    save_weights_only=False,  # Save the full model (not just weights)
    mode="max",  # Maximize validation accuracy
    verbose=1  # Print when the model is saved
)


model = build_u2net_3d_attn((128, 128, 64, 3), num_classes=4)

model.compile(
    optimizer=optim,
    loss='categorical_crossentropy',
    loss_weights=[1, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
    metrics=metrics 
)

# %%
from keras import backend as K

# %%
class MainOutputLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        print(f"\nEpoch {epoch + 1} - Main Output Metrics:")
        
        # Print training metrics
        print("Train:")
        for key in sorted(logs.keys()):
            if key.startswith("main_output") and not key.startswith("val_"):
                print(f"  {key}: {logs[key]:.4f}")

        # Print validation metrics
        print("Validation:")
        for key in sorted(logs.keys()):
            if key.startswith("val_main_output"):
                print(f"  {key}: {logs[key]:.4f}")

# %%
history=model.fit(train_img_datagen,
          steps_per_epoch=steps_per_epoch,
          epochs=200,
          verbose=0,
          validation_data=val_img_datagen,
          validation_steps=val_steps_per_epoch,
          callbacks=[checkpoint_cb, MainOutputLogger()],
          )
# Out:
# Epoch 1: val_main_output_dice_coef improved from -inf to 0.42791, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 1 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9608
#   main_output_dice_coef: 0.4247
#   main_output_loss: 0.1258
#   main_output_mean_io_u_1: 0.3750
#   main_output_precision: 0.9689
#   main_output_sensitivity: 0.9538
#   main_output_specificity: 0.9902
# Validation:
#   val_main_output_accuracy: 0.9569
#   val_main_output_dice_coef: 0.4279
#   val_main_output_loss: 0.1282
#   val_main_output_mean_io_u_1: 0.3750
#   val_main_output_precision: 0.9627
#   val_main_output_sensitivity: 0.9525
#   val_main_output_specificity: 0.9878
#
# Epoch 2: val_main_output_dice_coef improved from 0.42791 to 0.54427, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 2 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9747
#   main_output_dice_coef: 0.5290
#   main_output_loss: 0.0719
#   main_output_mean_io_u_1: 0.3753
#   main_output_precision: 0.9802
#   main_output_sensitivity: 0.9705
#   main_output_specificity: 0.9935
# Validation:
#   val_main_output_accuracy: 0.9695
#   val_main_output_dice_coef: 0.5443
#   val_main_output_loss: 0.0846
#   val_main_output_mean_io_u_1: 0.3750
#   val_main_output_precision: 0.9741
#   val_main_output_sensitivity: 0.9661
#   val_main_output_specificity: 0.9915
#
# Epoch 3: val_main_output_dice_coef improved from 0.54427 to 0.58699, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 3 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9790
#   main_output_dice_coef: 0.5851
#   main_output_loss: 0.0579
#   main_output_mean_io_u_1: 0.3758
#   main_output_precision: 0.9830
#   main_output_sensitivity: 0.9759
#   main_output_specificity: 0.9944
# Validation:
#   val_main_output_accuracy: 0.9730
#   val_main_output_dice_coef: 0.5870
#   val_main_output_loss: 0.0762
#   val_main_output_mean_io_u_1: 0.3750
#   val_main_output_precision: 0.9769
#   val_main_output_sensitivity: 0.9702
#   val_main_output_specificity: 0.9924
#
# Epoch 4: val_main_output_dice_coef improved from 0.58699 to 0.60215, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 4 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9820
#   main_output_dice_coef: 0.6292
#   main_output_loss: 0.0491
#   main_output_mean_io_u_1: 0.3765
#   main_output_precision: 0.9849
#   main_output_sensitivity: 0.9796
#   main_output_specificity: 0.9950
# Validation:
#   val_main_output_accuracy: 0.9698
#   val_main_output_dice_coef: 0.6021
#   val_main_output_loss: 0.0852
#   val_main_output_mean_io_u_1: 0.3750
#   val_main_output_precision: 0.9737
#   val_main_output_sensitivity: 0.9669
#   val_main_output_specificity: 0.9913
#
# Epoch 5: val_main_output_dice_coef improved from 0.60215 to 0.63373, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 5 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9835
#   main_output_dice_coef: 0.6575
#   main_output_loss: 0.0446
#   main_output_mean_io_u_1: 0.3792
#   main_output_precision: 0.9859
#   main_output_sensitivity: 0.9816
#   main_output_specificity: 0.9953
# Validation:
#   val_main_output_accuracy: 0.9750
#   val_main_output_dice_coef: 0.6337
#   val_main_output_loss: 0.0727
#   val_main_output_mean_io_u_1: 0.3752
#   val_main_output_precision: 0.9778
#   val_main_output_sensitivity: 0.9730
#   val_main_output_specificity: 0.9927
#
# Epoch 6: val_main_output_dice_coef did not improve from 0.63373
#
# Epoch 6 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9848
#   main_output_dice_coef: 0.6809
#   main_output_loss: 0.0410
#   main_output_mean_io_u_1: 0.3799
#   main_output_precision: 0.9869
#   main_output_sensitivity: 0.9832
#   main_output_specificity: 0.9957
# Validation:
#   val_main_output_accuracy: 0.9560
#   val_main_output_dice_coef: 0.6144
#   val_main_output_loss: 0.1430
#   val_main_output_mean_io_u_1: 0.3751
#   val_main_output_precision: 0.9605
#   val_main_output_sensitivity: 0.9526
#   val_main_output_specificity: 0.9871
#
# Epoch 7: val_main_output_dice_coef improved from 0.63373 to 0.68527, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 7 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9860
#   main_output_dice_coef: 0.7011
#   main_output_loss: 0.0375
#   main_output_mean_io_u_1: 0.3802
#   main_output_precision: 0.9877
#   main_output_sensitivity: 0.9846
#   main_output_specificity: 0.9959
# Validation:
#   val_main_output_accuracy: 0.9797
#   val_main_output_dice_coef: 0.6853
#   val_main_output_loss: 0.0642
#   val_main_output_mean_io_u_1: 0.3754
#   val_main_output_precision: 0.9814
#   val_main_output_sensitivity: 0.9784
#   val_main_output_specificity: 0.9938
#
# Epoch 8: val_main_output_dice_coef improved from 0.68527 to 0.70222, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 8 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9873
#   main_output_dice_coef: 0.7206
#   main_output_loss: 0.0340
#   main_output_mean_io_u_1: 0.3842
#   main_output_precision: 0.9888
#   main_output_sensitivity: 0.9861
#   main_output_specificity: 0.9963
# Validation:
#   val_main_output_accuracy: 0.9811
#   val_main_output_dice_coef: 0.7022
#   val_main_output_loss: 0.0591
#   val_main_output_mean_io_u_1: 0.3759
#   val_main_output_precision: 0.9827
#   val_main_output_sensitivity: 0.9799
#   val_main_output_specificity: 0.9943
#
# Epoch 9: val_main_output_dice_coef did not improve from 0.70222
#
# Epoch 9 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9873
#   main_output_dice_coef: 0.7249
#   main_output_loss: 0.0340
#   main_output_mean_io_u_1: 0.3841
#   main_output_precision: 0.9887
#   main_output_sensitivity: 0.9862
#   main_output_specificity: 0.9962
# Validation:
#   val_main_output_accuracy: 0.9807
#   val_main_output_dice_coef: 0.6963
#   val_main_output_loss: 0.0630
#   val_main_output_mean_io_u_1: 0.3886
#   val_main_output_precision: 0.9819
#   val_main_output_sensitivity: 0.9798
#   val_main_output_specificity: 0.9940
#
# Epoch 10: val_main_output_dice_coef improved from 0.70222 to 0.70755, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 10 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9880
#   main_output_dice_coef: 0.7352
#   main_output_loss: 0.0319
#   main_output_mean_io_u_1: 0.3859
#   main_output_precision: 0.9893
#   main_output_sensitivity: 0.9870
#   main_output_specificity: 0.9964
# Validation:
#   val_main_output_accuracy: 0.9820
#   val_main_output_dice_coef: 0.7076
#   val_main_output_loss: 0.0557
#   val_main_output_mean_io_u_1: 0.3776
#   val_main_output_precision: 0.9834
#   val_main_output_sensitivity: 0.9810
#   val_main_output_specificity: 0.9945
#
# Epoch 11: val_main_output_dice_coef improved from 0.70755 to 0.73279, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 11 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9895
#   main_output_dice_coef: 0.7580
#   main_output_loss: 0.0277
#   main_output_mean_io_u_1: 0.3919
#   main_output_precision: 0.9905
#   main_output_sensitivity: 0.9886
#   main_output_specificity: 0.9968
# Validation:
#   val_main_output_accuracy: 0.9839
#   val_main_output_dice_coef: 0.7328
#   val_main_output_loss: 0.0539
#   val_main_output_mean_io_u_1: 0.3915
#   val_main_output_precision: 0.9848
#   val_main_output_sensitivity: 0.9833
#   val_main_output_specificity: 0.9950
#
# Epoch 12: val_main_output_dice_coef did not improve from 0.73279
#
# Epoch 12 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9894
#   main_output_dice_coef: 0.7611
#   main_output_loss: 0.0279
#   main_output_mean_io_u_1: 0.3948
#   main_output_precision: 0.9903
#   main_output_sensitivity: 0.9886
#   main_output_specificity: 0.9968
# Validation:
#   val_main_output_accuracy: 0.9849
#   val_main_output_dice_coef: 0.7310
#   val_main_output_loss: 0.0473
#   val_main_output_mean_io_u_1: 0.3816
#   val_main_output_precision: 0.9859
#   val_main_output_sensitivity: 0.9842
#   val_main_output_specificity: 0.9953
#
# Epoch 13: val_main_output_dice_coef improved from 0.73279 to 0.74680, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 13 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9899
#   main_output_dice_coef: 0.7678
#   main_output_loss: 0.0265
#   main_output_mean_io_u_1: 0.3997
#   main_output_precision: 0.9908
#   main_output_sensitivity: 0.9892
#   main_output_specificity: 0.9969
# Validation:
#   val_main_output_accuracy: 0.9856
#   val_main_output_dice_coef: 0.7468
#   val_main_output_loss: 0.0473
#   val_main_output_mean_io_u_1: 0.3844
#   val_main_output_precision: 0.9864
#   val_main_output_sensitivity: 0.9850
#   val_main_output_specificity: 0.9955
#
# Epoch 14: val_main_output_dice_coef did not improve from 0.74680
#
# Epoch 14 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9897
#   main_output_dice_coef: 0.7695
#   main_output_loss: 0.0270
#   main_output_mean_io_u_1: 0.4033
#   main_output_precision: 0.9906
#   main_output_sensitivity: 0.9889
#   main_output_specificity: 0.9969
# Validation:
#   val_main_output_accuracy: 0.9860
#   val_main_output_dice_coef: 0.7457
#   val_main_output_loss: 0.0462
#   val_main_output_mean_io_u_1: 0.3921
#   val_main_output_precision: 0.9869
#   val_main_output_sensitivity: 0.9853
#   val_main_output_specificity: 0.9957
#
# Epoch 15: val_main_output_dice_coef did not improve from 0.74680
#
# Epoch 15 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9900
#   main_output_dice_coef: 0.7759
#   main_output_loss: 0.0261
#   main_output_mean_io_u_1: 0.4053
#   main_output_precision: 0.9909
#   main_output_sensitivity: 0.9893
#   main_output_specificity: 0.9970
# Validation:
#   val_main_output_accuracy: 0.9849
#   val_main_output_dice_coef: 0.7423
#   val_main_output_loss: 0.0483
#   val_main_output_mean_io_u_1: 0.4035
#   val_main_output_precision: 0.9859
#   val_main_output_sensitivity: 0.9842
#   val_main_output_specificity: 0.9953
#
# Epoch 16: val_main_output_dice_coef did not improve from 0.74680
#
# Epoch 16 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9904
#   main_output_dice_coef: 0.7787
#   main_output_loss: 0.0250
#   main_output_mean_io_u_1: 0.4241
#   main_output_precision: 0.9912
#   main_output_sensitivity: 0.9897
#   main_output_specificity: 0.9971
# Validation:
#   val_main_output_accuracy: 0.9794
#   val_main_output_dice_coef: 0.7160
#   val_main_output_loss: 0.0688
#   val_main_output_mean_io_u_1: 0.4059
#   val_main_output_precision: 0.9808
#   val_main_output_sensitivity: 0.9784
#   val_main_output_specificity: 0.9936
#
# Epoch 17: val_main_output_dice_coef improved from 0.74680 to 0.74759, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 17 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9912
#   main_output_dice_coef: 0.7915
#   main_output_loss: 0.0229
#   main_output_mean_io_u_1: 0.4397
#   main_output_precision: 0.9919
#   main_output_sensitivity: 0.9906
#   main_output_specificity: 0.9973
# Validation:
#   val_main_output_accuracy: 0.9852
#   val_main_output_dice_coef: 0.7476
#   val_main_output_loss: 0.0478
#   val_main_output_mean_io_u_1: 0.4121
#   val_main_output_precision: 0.9862
#   val_main_output_sensitivity: 0.9845
#   val_main_output_specificity: 0.9954
#
# Epoch 18: val_main_output_dice_coef improved from 0.74759 to 0.76386, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 18 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9914
#   main_output_dice_coef: 0.7966
#   main_output_loss: 0.0223
#   main_output_mean_io_u_1: 0.4470
#   main_output_precision: 0.9920
#   main_output_sensitivity: 0.9908
#   main_output_specificity: 0.9973
# Validation:
#   val_main_output_accuracy: 0.9866
#   val_main_output_dice_coef: 0.7639
#   val_main_output_loss: 0.0456
#   val_main_output_mean_io_u_1: 0.4431
#   val_main_output_precision: 0.9873
#   val_main_output_sensitivity: 0.9860
#   val_main_output_specificity: 0.9958
#
# Epoch 19: val_main_output_dice_coef did not improve from 0.76386
#
# Epoch 19 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9914
#   main_output_dice_coef: 0.7984
#   main_output_loss: 0.0222
#   main_output_mean_io_u_1: 0.4641
#   main_output_precision: 0.9921
#   main_output_sensitivity: 0.9909
#   main_output_specificity: 0.9974
# Validation:
#   val_main_output_accuracy: 0.9865
#   val_main_output_dice_coef: 0.7622
#   val_main_output_loss: 0.0437
#   val_main_output_mean_io_u_1: 0.4392
#   val_main_output_precision: 0.9874
#   val_main_output_sensitivity: 0.9859
#   val_main_output_specificity: 0.9958
#
# Epoch 20: val_main_output_dice_coef improved from 0.76386 to 0.76847, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 20 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9917
#   main_output_dice_coef: 0.8054
#   main_output_loss: 0.0214
#   main_output_mean_io_u_1: 0.4692
#   main_output_precision: 0.9923
#   main_output_sensitivity: 0.9912
#   main_output_specificity: 0.9975
# Validation:
#   val_main_output_accuracy: 0.9865
#   val_main_output_dice_coef: 0.7685
#   val_main_output_loss: 0.0447
#   val_main_output_mean_io_u_1: 0.4530
#   val_main_output_precision: 0.9872
#   val_main_output_sensitivity: 0.9860
#   val_main_output_specificity: 0.9957
#
# Epoch 21: val_main_output_dice_coef improved from 0.76847 to 0.77820, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 21 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9921
#   main_output_dice_coef: 0.8121
#   main_output_loss: 0.0205
#   main_output_mean_io_u_1: 0.4887
#   main_output_precision: 0.9926
#   main_output_sensitivity: 0.9916
#   main_output_specificity: 0.9975
# Validation:
#   val_main_output_accuracy: 0.9872
#   val_main_output_dice_coef: 0.7782
#   val_main_output_loss: 0.0451
#   val_main_output_mean_io_u_1: 0.5083
#   val_main_output_precision: 0.9878
#   val_main_output_sensitivity: 0.9867
#   val_main_output_specificity: 0.9959
#
# Epoch 22: val_main_output_dice_coef did not improve from 0.77820
#
# Epoch 22 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9912
#   main_output_dice_coef: 0.7999
#   main_output_loss: 0.0227
#   main_output_mean_io_u_1: 0.4838
#   main_output_precision: 0.9919
#   main_output_sensitivity: 0.9907
#   main_output_specificity: 0.9973
# Validation:
#   val_main_output_accuracy: 0.9829
#   val_main_output_dice_coef: 0.7414
#   val_main_output_loss: 0.0513
#   val_main_output_mean_io_u_1: 0.5109
#   val_main_output_precision: 0.9841
#   val_main_output_sensitivity: 0.9821
#   val_main_output_specificity: 0.9947
#
# Epoch 23: val_main_output_dice_coef did not improve from 0.77820
#
# Epoch 23 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9920
#   main_output_dice_coef: 0.8120
#   main_output_loss: 0.0208
#   main_output_mean_io_u_1: 0.4949
#   main_output_precision: 0.9925
#   main_output_sensitivity: 0.9915
#   main_output_specificity: 0.9975
# Validation:
#   val_main_output_accuracy: 0.9869
#   val_main_output_dice_coef: 0.7744
#   val_main_output_loss: 0.0452
#   val_main_output_mean_io_u_1: 0.5417
#   val_main_output_precision: 0.9876
#   val_main_output_sensitivity: 0.9864
#   val_main_output_specificity: 0.9959
#
# Epoch 24: val_main_output_dice_coef did not improve from 0.77820
#
# Epoch 24 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9922
#   main_output_dice_coef: 0.8175
#   main_output_loss: 0.0200
#   main_output_mean_io_u_1: 0.5226
#   main_output_precision: 0.9928
#   main_output_sensitivity: 0.9918
#   main_output_specificity: 0.9976
# Validation:
#   val_main_output_accuracy: 0.9858
#   val_main_output_dice_coef: 0.7712
#   val_main_output_loss: 0.0469
#   val_main_output_mean_io_u_1: 0.5016
#   val_main_output_precision: 0.9865
#   val_main_output_sensitivity: 0.9852
#   val_main_output_specificity: 0.9955
#
# Epoch 25: val_main_output_dice_coef improved from 0.77820 to 0.78476, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 25 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9926
#   main_output_dice_coef: 0.8248
#   main_output_loss: 0.0189
#   main_output_mean_io_u_1: 0.5432
#   main_output_precision: 0.9931
#   main_output_sensitivity: 0.9923
#   main_output_specificity: 0.9977
# Validation:
#   val_main_output_accuracy: 0.9871
#   val_main_output_dice_coef: 0.7848
#   val_main_output_loss: 0.0458
#   val_main_output_mean_io_u_1: 0.5849
#   val_main_output_precision: 0.9877
#   val_main_output_sensitivity: 0.9867
#   val_main_output_specificity: 0.9959
#
# Epoch 26: val_main_output_dice_coef did not improve from 0.78476
#
# Epoch 26 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9921
#   main_output_dice_coef: 0.8175
#   main_output_loss: 0.0202
#   main_output_mean_io_u_1: 0.5359
#   main_output_precision: 0.9926
#   main_output_sensitivity: 0.9917
#   main_output_specificity: 0.9975
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.7835
#   val_main_output_loss: 0.0403
#   val_main_output_mean_io_u_1: 0.5359
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9874
#   val_main_output_specificity: 0.9962
#
# Epoch 27: val_main_output_dice_coef did not improve from 0.78476
#
# Epoch 27 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9925
#   main_output_dice_coef: 0.8251
#   main_output_loss: 0.0192
#   main_output_mean_io_u_1: 0.5563
#   main_output_precision: 0.9930
#   main_output_sensitivity: 0.9921
#   main_output_specificity: 0.9977
# Validation:
#   val_main_output_accuracy: 0.9877
#   val_main_output_dice_coef: 0.7813
#   val_main_output_loss: 0.0417
#   val_main_output_mean_io_u_1: 0.6013
#   val_main_output_precision: 0.9883
#   val_main_output_sensitivity: 0.9872
#   val_main_output_specificity: 0.9961
#
# Epoch 28: val_main_output_dice_coef improved from 0.78476 to 0.78769, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 28 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9930
#   main_output_dice_coef: 0.8316
#   main_output_loss: 0.0178
#   main_output_mean_io_u_1: 0.5905
#   main_output_precision: 0.9935
#   main_output_sensitivity: 0.9927
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.7877
#   val_main_output_loss: 0.0416
#   val_main_output_mean_io_u_1: 0.5480
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9875
#   val_main_output_specificity: 0.9961
#
# Epoch 29: val_main_output_dice_coef did not improve from 0.78769
#
# Epoch 29 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9929
#   main_output_dice_coef: 0.8306
#   main_output_loss: 0.0182
#   main_output_mean_io_u_1: 0.5976
#   main_output_precision: 0.9933
#   main_output_sensitivity: 0.9926
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9881
#   val_main_output_dice_coef: 0.7871
#   val_main_output_loss: 0.0404
#   val_main_output_mean_io_u_1: 0.5694
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9962
#
# Epoch 30: val_main_output_dice_coef did not improve from 0.78769
#
# Epoch 30 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9931
#   main_output_dice_coef: 0.8334
#   main_output_loss: 0.0177
#   main_output_mean_io_u_1: 0.6113
#   main_output_precision: 0.9935
#   main_output_sensitivity: 0.9927
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.7863
#   val_main_output_loss: 0.0410
#   val_main_output_mean_io_u_1: 0.5585
#   val_main_output_precision: 0.9881
#   val_main_output_sensitivity: 0.9871
#   val_main_output_specificity: 0.9960
#
# Epoch 31: val_main_output_dice_coef did not improve from 0.78769
#
# Epoch 31 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9933
#   main_output_dice_coef: 0.8364
#   main_output_loss: 0.0172
#   main_output_mean_io_u_1: 0.6086
#   main_output_precision: 0.9937
#   main_output_sensitivity: 0.9929
#   main_output_specificity: 0.9979
# Validation:
#   val_main_output_accuracy: 0.9852
#   val_main_output_dice_coef: 0.7846
#   val_main_output_loss: 0.0495
#   val_main_output_mean_io_u_1: 0.5584
#   val_main_output_precision: 0.9857
#   val_main_output_sensitivity: 0.9848
#   val_main_output_specificity: 0.9952
#
# Epoch 32: val_main_output_dice_coef improved from 0.78769 to 0.79061, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 32 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9931
#   main_output_dice_coef: 0.8360
#   main_output_loss: 0.0175
#   main_output_mean_io_u_1: 0.6211
#   main_output_precision: 0.9936
#   main_output_sensitivity: 0.9928
#   main_output_specificity: 0.9979
# Validation:
#   val_main_output_accuracy: 0.9869
#   val_main_output_dice_coef: 0.7906
#   val_main_output_loss: 0.0447
#   val_main_output_mean_io_u_1: 0.5176
#   val_main_output_precision: 0.9874
#   val_main_output_sensitivity: 0.9865
#   val_main_output_specificity: 0.9958
#
# Epoch 33: val_main_output_dice_coef did not improve from 0.79061
#
# Epoch 33 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9929
#   main_output_dice_coef: 0.8307
#   main_output_loss: 0.0183
#   main_output_mean_io_u_1: 0.6009
#   main_output_precision: 0.9933
#   main_output_sensitivity: 0.9925
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9868
#   val_main_output_dice_coef: 0.7878
#   val_main_output_loss: 0.0468
#   val_main_output_mean_io_u_1: 0.5208
#   val_main_output_precision: 0.9873
#   val_main_output_sensitivity: 0.9865
#   val_main_output_specificity: 0.9958
#
# Epoch 34: val_main_output_dice_coef improved from 0.79061 to 0.79520, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 34 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9933
#   main_output_dice_coef: 0.8405
#   main_output_loss: 0.0171
#   main_output_mean_io_u_1: 0.6187
#   main_output_precision: 0.9937
#   main_output_sensitivity: 0.9930
#   main_output_specificity: 0.9979
# Validation:
#   val_main_output_accuracy: 0.9876
#   val_main_output_dice_coef: 0.7952
#   val_main_output_loss: 0.0438
#   val_main_output_mean_io_u_1: 0.5673
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9872
#   val_main_output_specificity: 0.9960
#
# Epoch 35: val_main_output_dice_coef did not improve from 0.79520
#
# Epoch 35 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9932
#   main_output_dice_coef: 0.8401
#   main_output_loss: 0.0173
#   main_output_mean_io_u_1: 0.6292
#   main_output_precision: 0.9936
#   main_output_sensitivity: 0.9929
#   main_output_specificity: 0.9979
# Validation:
#   val_main_output_accuracy: 0.9877
#   val_main_output_dice_coef: 0.7923
#   val_main_output_loss: 0.0435
#   val_main_output_mean_io_u_1: 0.5923
#   val_main_output_precision: 0.9882
#   val_main_output_sensitivity: 0.9873
#   val_main_output_specificity: 0.9961
#
# Epoch 36: val_main_output_dice_coef did not improve from 0.79520
#
# Epoch 36 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9928
#   main_output_dice_coef: 0.8306
#   main_output_loss: 0.0183
#   main_output_mean_io_u_1: 0.6272
#   main_output_precision: 0.9933
#   main_output_sensitivity: 0.9925
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9869
#   val_main_output_dice_coef: 0.7796
#   val_main_output_loss: 0.0433
#   val_main_output_mean_io_u_1: 0.5812
#   val_main_output_precision: 0.9876
#   val_main_output_sensitivity: 0.9865
#   val_main_output_specificity: 0.9959
#
# Epoch 37: val_main_output_dice_coef improved from 0.79520 to 0.79758, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 37 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9934
#   main_output_dice_coef: 0.8431
#   main_output_loss: 0.0168
#   main_output_mean_io_u_1: 0.6288
#   main_output_precision: 0.9938
#   main_output_sensitivity: 0.9931
#   main_output_specificity: 0.9979
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.7976
#   val_main_output_loss: 0.0439
#   val_main_output_mean_io_u_1: 0.5781
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9871
#   val_main_output_specificity: 0.9960
#
# Epoch 38: val_main_output_dice_coef improved from 0.79758 to 0.80221, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 38 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9938
#   main_output_dice_coef: 0.8514
#   main_output_loss: 0.0158
#   main_output_mean_io_u_1: 0.6390
#   main_output_precision: 0.9941
#   main_output_sensitivity: 0.9935
#   main_output_specificity: 0.9980
# Validation:
#   val_main_output_accuracy: 0.9882
#   val_main_output_dice_coef: 0.8022
#   val_main_output_loss: 0.0444
#   val_main_output_mean_io_u_1: 0.6373
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9879
#   val_main_output_specificity: 0.9962
#
# Epoch 39: val_main_output_dice_coef did not improve from 0.80221
#
# Epoch 39 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9940
#   main_output_dice_coef: 0.8558
#   main_output_loss: 0.0151
#   main_output_mean_io_u_1: 0.6404
#   main_output_precision: 0.9943
#   main_output_sensitivity: 0.9938
#   main_output_specificity: 0.9981
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.7961
#   val_main_output_loss: 0.0445
#   val_main_output_mean_io_u_1: 0.6124
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9871
#   val_main_output_specificity: 0.9960
#
# Epoch 40: val_main_output_dice_coef did not improve from 0.80221
#
# Epoch 40 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9938
#   main_output_dice_coef: 0.8543
#   main_output_loss: 0.0156
#   main_output_mean_io_u_1: 0.6366
#   main_output_precision: 0.9941
#   main_output_sensitivity: 0.9936
#   main_output_specificity: 0.9981
# Validation:
#   val_main_output_accuracy: 0.9878
#   val_main_output_dice_coef: 0.7933
#   val_main_output_loss: 0.0409
#   val_main_output_mean_io_u_1: 0.6095
#   val_main_output_precision: 0.9883
#   val_main_output_sensitivity: 0.9875
#   val_main_output_specificity: 0.9961
#
# Epoch 41: val_main_output_dice_coef did not improve from 0.80221
#
# Epoch 41 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9929
#   main_output_dice_coef: 0.8346
#   main_output_loss: 0.0182
#   main_output_mean_io_u_1: 0.5823
#   main_output_precision: 0.9933
#   main_output_sensitivity: 0.9926
#   main_output_specificity: 0.9978
# Validation:
#   val_main_output_accuracy: 0.9878
#   val_main_output_dice_coef: 0.7842
#   val_main_output_loss: 0.0427
#   val_main_output_mean_io_u_1: 0.6464
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9873
#   val_main_output_specificity: 0.9962
#
# Epoch 42: val_main_output_dice_coef improved from 0.80221 to 0.80290, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 42 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9937
#   main_output_dice_coef: 0.8471
#   main_output_loss: 0.0160
#   main_output_mean_io_u_1: 0.6276
#   main_output_precision: 0.9941
#   main_output_sensitivity: 0.9934
#   main_output_specificity: 0.9980
# Validation:
#   val_main_output_accuracy: 0.9881
#   val_main_output_dice_coef: 0.8029
#   val_main_output_loss: 0.0440
#   val_main_output_mean_io_u_1: 0.5945
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9878
#   val_main_output_specificity: 0.9962
#
# Epoch 43: val_main_output_dice_coef improved from 0.80290 to 0.80354, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 43 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9943
#   main_output_dice_coef: 0.8567
#   main_output_loss: 0.0144
#   main_output_mean_io_u_1: 0.6490
#   main_output_precision: 0.9946
#   main_output_sensitivity: 0.9940
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9866
#   val_main_output_dice_coef: 0.8035
#   val_main_output_loss: 0.0495
#   val_main_output_mean_io_u_1: 0.5692
#   val_main_output_precision: 0.9870
#   val_main_output_sensitivity: 0.9863
#   val_main_output_specificity: 0.9957
#
# Epoch 44: val_main_output_dice_coef did not improve from 0.80354
#
# Epoch 44 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9941
#   main_output_dice_coef: 0.8550
#   main_output_loss: 0.0150
#   main_output_mean_io_u_1: 0.6665
#   main_output_precision: 0.9944
#   main_output_sensitivity: 0.9938
#   main_output_specificity: 0.9981
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.8035
#   val_main_output_loss: 0.0498
#   val_main_output_mean_io_u_1: 0.6611
#   val_main_output_precision: 0.9879
#   val_main_output_sensitivity: 0.9873
#   val_main_output_specificity: 0.9960
#
# Epoch 45: val_main_output_dice_coef did not improve from 0.80354
#
# Epoch 45 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9943
#   main_output_dice_coef: 0.8568
#   main_output_loss: 0.0146
#   main_output_mean_io_u_1: 0.6785
#   main_output_precision: 0.9946
#   main_output_sensitivity: 0.9940
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.8013
#   val_main_output_loss: 0.0442
#   val_main_output_mean_io_u_1: 0.5884
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9876
#   val_main_output_specificity: 0.9961
#
# Epoch 46: val_main_output_dice_coef improved from 0.80354 to 0.80469, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 46 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9945
#   main_output_dice_coef: 0.8613
#   main_output_loss: 0.0140
#   main_output_mean_io_u_1: 0.6735
#   main_output_precision: 0.9948
#   main_output_sensitivity: 0.9943
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9873
#   val_main_output_dice_coef: 0.8047
#   val_main_output_loss: 0.0471
#   val_main_output_mean_io_u_1: 0.6327
#   val_main_output_precision: 0.9877
#   val_main_output_sensitivity: 0.9870
#   val_main_output_specificity: 0.9959
#
# Epoch 47: val_main_output_dice_coef improved from 0.80469 to 0.80689, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 47 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9944
#   main_output_dice_coef: 0.8611
#   main_output_loss: 0.0141
#   main_output_mean_io_u_1: 0.6742
#   main_output_precision: 0.9947
#   main_output_sensitivity: 0.9942
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9881
#   val_main_output_dice_coef: 0.8069
#   val_main_output_loss: 0.0443
#   val_main_output_mean_io_u_1: 0.6199
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9879
#   val_main_output_specificity: 0.9962
#
# Epoch 48: val_main_output_dice_coef did not improve from 0.80689
#
# Epoch 48 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9942
#   main_output_dice_coef: 0.8590
#   main_output_loss: 0.0149
#   main_output_mean_io_u_1: 0.6596
#   main_output_precision: 0.9945
#   main_output_sensitivity: 0.9939
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9886
#   val_main_output_dice_coef: 0.8037
#   val_main_output_loss: 0.0395
#   val_main_output_mean_io_u_1: 0.5914
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9963
#
# Epoch 49: val_main_output_dice_coef did not improve from 0.80689
#
# Epoch 49 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9941
#   main_output_dice_coef: 0.8581
#   main_output_loss: 0.0149
#   main_output_mean_io_u_1: 0.6497
#   main_output_precision: 0.9944
#   main_output_sensitivity: 0.9939
#   main_output_specificity: 0.9981
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.8032
#   val_main_output_loss: 0.0459
#   val_main_output_mean_io_u_1: 0.5829
#   val_main_output_precision: 0.9878
#   val_main_output_sensitivity: 0.9872
#   val_main_output_specificity: 0.9960
#
# Epoch 50: val_main_output_dice_coef did not improve from 0.80689
#
# Epoch 50 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9945
#   main_output_dice_coef: 0.8639
#   main_output_loss: 0.0140
#   main_output_mean_io_u_1: 0.6851
#   main_output_precision: 0.9947
#   main_output_sensitivity: 0.9942
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.8031
#   val_main_output_loss: 0.0443
#   val_main_output_mean_io_u_1: 0.6637
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9876
#   val_main_output_specificity: 0.9961
#
# Epoch 51: val_main_output_dice_coef improved from 0.80689 to 0.80731, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 51 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9943
#   main_output_dice_coef: 0.8641
#   main_output_loss: 0.0143
#   main_output_mean_io_u_1: 0.6888
#   main_output_precision: 0.9946
#   main_output_sensitivity: 0.9941
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8073
#   val_main_output_loss: 0.0452
#   val_main_output_mean_io_u_1: 0.7045
#   val_main_output_precision: 0.9887
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9962
#
# Epoch 52: val_main_output_dice_coef improved from 0.80731 to 0.80790, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 52 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9942
#   main_output_dice_coef: 0.8618
#   main_output_loss: 0.0146
#   main_output_mean_io_u_1: 0.6763
#   main_output_precision: 0.9945
#   main_output_sensitivity: 0.9940
#   main_output_specificity: 0.9982
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8079
#   val_main_output_loss: 0.0446
#   val_main_output_mean_io_u_1: 0.6716
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9963
#
# Epoch 53: val_main_output_dice_coef did not improve from 0.80790
#
# Epoch 53 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9942
#   main_output_dice_coef: 0.8614
#   main_output_loss: 0.0147
#   main_output_mean_io_u_1: 0.6876
#   main_output_precision: 0.9944
#   main_output_sensitivity: 0.9939
#   main_output_specificity: 0.9981
# Validation:
#   val_main_output_accuracy: 0.9880
#   val_main_output_dice_coef: 0.8010
#   val_main_output_loss: 0.0454
#   val_main_output_mean_io_u_1: 0.5495
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9961
#
# Epoch 54: val_main_output_dice_coef did not improve from 0.80790
#
# Epoch 54 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9935
#   main_output_dice_coef: 0.8460
#   main_output_loss: 0.0165
#   main_output_mean_io_u_1: 0.6607
#   main_output_precision: 0.9939
#   main_output_sensitivity: 0.9932
#   main_output_specificity: 0.9980
# Validation:
#   val_main_output_accuracy: 0.9877
#   val_main_output_dice_coef: 0.8043
#   val_main_output_loss: 0.0468
#   val_main_output_mean_io_u_1: 0.7045
#   val_main_output_precision: 0.9881
#   val_main_output_sensitivity: 0.9874
#   val_main_output_specificity: 0.9960
#
# Epoch 55: val_main_output_dice_coef improved from 0.80790 to 0.81004, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 55 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9946
#   main_output_dice_coef: 0.8655
#   main_output_loss: 0.0136
#   main_output_mean_io_u_1: 0.7016
#   main_output_precision: 0.9949
#   main_output_sensitivity: 0.9944
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8100
#   val_main_output_loss: 0.0460
#   val_main_output_mean_io_u_1: 0.7378
#   val_main_output_precision: 0.9887
#   val_main_output_sensitivity: 0.9880
#   val_main_output_specificity: 0.9962
#
# Epoch 56: val_main_output_dice_coef improved from 0.81004 to 0.81205, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 56 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9950
#   main_output_dice_coef: 0.8725
#   main_output_loss: 0.0126
#   main_output_mean_io_u_1: 0.7155
#   main_output_precision: 0.9952
#   main_output_sensitivity: 0.9948
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8121
#   val_main_output_loss: 0.0468
#   val_main_output_mean_io_u_1: 0.6763
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9963
#
# Epoch 57: val_main_output_dice_coef improved from 0.81205 to 0.81224, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 57 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9949
#   main_output_dice_coef: 0.8744
#   main_output_loss: 0.0127
#   main_output_mean_io_u_1: 0.7299
#   main_output_precision: 0.9952
#   main_output_sensitivity: 0.9948
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.8122
#   val_main_output_loss: 0.0482
#   val_main_output_mean_io_u_1: 0.6895
#   val_main_output_precision: 0.9882
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9961
#
# Epoch 58: val_main_output_dice_coef did not improve from 0.81224
#
# Epoch 58 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9947
#   main_output_dice_coef: 0.8722
#   main_output_loss: 0.0132
#   main_output_mean_io_u_1: 0.7297
#   main_output_precision: 0.9950
#   main_output_sensitivity: 0.9945
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9878
#   val_main_output_dice_coef: 0.8092
#   val_main_output_loss: 0.0461
#   val_main_output_mean_io_u_1: 0.6297
#   val_main_output_precision: 0.9882
#   val_main_output_sensitivity: 0.9876
#   val_main_output_specificity: 0.9961
#
# Epoch 59: val_main_output_dice_coef did not improve from 0.81224
#
# Epoch 59 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9945
#   main_output_dice_coef: 0.8685
#   main_output_loss: 0.0137
#   main_output_mean_io_u_1: 0.7044
#   main_output_precision: 0.9948
#   main_output_sensitivity: 0.9943
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9882
#   val_main_output_dice_coef: 0.8102
#   val_main_output_loss: 0.0462
#   val_main_output_mean_io_u_1: 0.6788
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9880
#   val_main_output_specificity: 0.9962
#
# Epoch 60: val_main_output_dice_coef did not improve from 0.81224
#
# Epoch 60 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9945
#   main_output_dice_coef: 0.8686
#   main_output_loss: 0.0137
#   main_output_mean_io_u_1: 0.6853
#   main_output_precision: 0.9948
#   main_output_sensitivity: 0.9943
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9874
#   val_main_output_dice_coef: 0.8051
#   val_main_output_loss: 0.0455
#   val_main_output_mean_io_u_1: 0.6908
#   val_main_output_precision: 0.9878
#   val_main_output_sensitivity: 0.9871
#   val_main_output_specificity: 0.9959
#
# Epoch 61: val_main_output_dice_coef did not improve from 0.81224
#
# Epoch 61 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9947
#   main_output_dice_coef: 0.8710
#   main_output_loss: 0.0133
#   main_output_mean_io_u_1: 0.6841
#   main_output_precision: 0.9950
#   main_output_sensitivity: 0.9945
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8090
#   val_main_output_loss: 0.0455
#   val_main_output_mean_io_u_1: 0.6611
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9963
#
# Epoch 62: val_main_output_dice_coef improved from 0.81224 to 0.81407, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 62 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9948
#   main_output_dice_coef: 0.8725
#   main_output_loss: 0.0129
#   main_output_mean_io_u_1: 0.7145
#   main_output_precision: 0.9951
#   main_output_sensitivity: 0.9946
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9885
#   val_main_output_dice_coef: 0.8141
#   val_main_output_loss: 0.0454
#   val_main_output_mean_io_u_1: 0.6598
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9963
#
# Epoch 63: val_main_output_dice_coef improved from 0.81407 to 0.81415, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 63 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9951
#   main_output_dice_coef: 0.8756
#   main_output_loss: 0.0123
#   main_output_mean_io_u_1: 0.7211
#   main_output_precision: 0.9953
#   main_output_sensitivity: 0.9949
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8142
#   val_main_output_loss: 0.0460
#   val_main_output_mean_io_u_1: 0.6671
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9963
#
# Epoch 64: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 64 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9952
#   main_output_dice_coef: 0.8765
#   main_output_loss: 0.0121
#   main_output_mean_io_u_1: 0.7333
#   main_output_precision: 0.9954
#   main_output_sensitivity: 0.9950
#   main_output_specificity: 0.9985
# Validation:
#   val_main_output_accuracy: 0.9886
#   val_main_output_dice_coef: 0.8141
#   val_main_output_loss: 0.0453
#   val_main_output_mean_io_u_1: 0.7472
#   val_main_output_precision: 0.9889
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9963
#
# Epoch 65: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 65 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9951
#   main_output_dice_coef: 0.8764
#   main_output_loss: 0.0124
#   main_output_mean_io_u_1: 0.7364
#   main_output_precision: 0.9953
#   main_output_sensitivity: 0.9949
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8140
#   val_main_output_loss: 0.0488
#   val_main_output_mean_io_u_1: 0.7575
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9880
#   val_main_output_specificity: 0.9962
#
# Epoch 66: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 66 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9948
#   main_output_dice_coef: 0.8752
#   main_output_loss: 0.0130
#   main_output_mean_io_u_1: 0.7204
#   main_output_precision: 0.9950
#   main_output_sensitivity: 0.9946
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9880
#   val_main_output_dice_coef: 0.8131
#   val_main_output_loss: 0.0477
#   val_main_output_mean_io_u_1: 0.7290
#   val_main_output_precision: 0.9883
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9961
#
# Epoch 67: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 67 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9947
#   main_output_dice_coef: 0.8740
#   main_output_loss: 0.0132
#   main_output_mean_io_u_1: 0.7259
#   main_output_precision: 0.9950
#   main_output_sensitivity: 0.9946
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9876
#   val_main_output_dice_coef: 0.8098
#   val_main_output_loss: 0.0482
#   val_main_output_mean_io_u_1: 0.7427
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9873
#   val_main_output_specificity: 0.9960
#
# Epoch 68: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 68 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9947
#   main_output_dice_coef: 0.8728
#   main_output_loss: 0.0133
#   main_output_mean_io_u_1: 0.7170
#   main_output_precision: 0.9949
#   main_output_sensitivity: 0.9945
#   main_output_specificity: 0.9983
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8124
#   val_main_output_loss: 0.0476
#   val_main_output_mean_io_u_1: 0.7844
#   val_main_output_precision: 0.9887
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9963
#
# Epoch 69: val_main_output_dice_coef did not improve from 0.81415
#
# Epoch 69 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9948
#   main_output_dice_coef: 0.8757
#   main_output_loss: 0.0129
#   main_output_mean_io_u_1: 0.7240
#   main_output_precision: 0.9951
#   main_output_sensitivity: 0.9947
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9885
#   val_main_output_dice_coef: 0.8090
#   val_main_output_loss: 0.0446
#   val_main_output_mean_io_u_1: 0.7165
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9963
#
# Epoch 70: val_main_output_dice_coef improved from 0.81415 to 0.81816, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 70 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9951
#   main_output_dice_coef: 0.8791
#   main_output_loss: 0.0123
#   main_output_mean_io_u_1: 0.7442
#   main_output_precision: 0.9953
#   main_output_sensitivity: 0.9949
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8182
#   val_main_output_loss: 0.0459
#   val_main_output_mean_io_u_1: 0.6622
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9962
#
# Epoch 71: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 71 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9952
#   main_output_dice_coef: 0.8786
#   main_output_loss: 0.0120
#   main_output_mean_io_u_1: 0.7482
#   main_output_precision: 0.9954
#   main_output_sensitivity: 0.9950
#   main_output_specificity: 0.9985
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8174
#   val_main_output_loss: 0.0464
#   val_main_output_mean_io_u_1: 0.7283
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9962
#
# Epoch 72: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 72 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9953
#   main_output_dice_coef: 0.8812
#   main_output_loss: 0.0117
#   main_output_mean_io_u_1: 0.7600
#   main_output_precision: 0.9955
#   main_output_sensitivity: 0.9952
#   main_output_specificity: 0.9985
# Validation:
#   val_main_output_accuracy: 0.9880
#   val_main_output_dice_coef: 0.8174
#   val_main_output_loss: 0.0483
#   val_main_output_mean_io_u_1: 0.7457
#   val_main_output_precision: 0.9883
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9961
#
# Epoch 73: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 73 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9954
#   main_output_dice_coef: 0.8831
#   main_output_loss: 0.0115
#   main_output_mean_io_u_1: 0.7612
#   main_output_precision: 0.9956
#   main_output_sensitivity: 0.9952
#   main_output_specificity: 0.9985
# Validation:
#   val_main_output_accuracy: 0.9875
#   val_main_output_dice_coef: 0.8099
#   val_main_output_loss: 0.0541
#   val_main_output_mean_io_u_1: 0.8026
#   val_main_output_precision: 0.9879
#   val_main_output_sensitivity: 0.9873
#   val_main_output_specificity: 0.9960
#
# Epoch 74: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 74 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9952
#   main_output_dice_coef: 0.8826
#   main_output_loss: 0.0120
#   main_output_mean_io_u_1: 0.7657
#   main_output_precision: 0.9954
#   main_output_sensitivity: 0.9950
#   main_output_specificity: 0.9985
# Validation:
#   val_main_output_accuracy: 0.9878
#   val_main_output_dice_coef: 0.8074
#   val_main_output_loss: 0.0516
#   val_main_output_mean_io_u_1: 0.8186
#   val_main_output_precision: 0.9881
#   val_main_output_sensitivity: 0.9875
#   val_main_output_specificity: 0.9960
#
# Epoch 75: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 75 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9951
#   main_output_dice_coef: 0.8822
#   main_output_loss: 0.0121
#   main_output_mean_io_u_1: 0.7617
#   main_output_precision: 0.9953
#   main_output_sensitivity: 0.9950
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9877
#   val_main_output_dice_coef: 0.8098
#   val_main_output_loss: 0.0533
#   val_main_output_mean_io_u_1: 0.8318
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9874
#   val_main_output_specificity: 0.9960
#
# Epoch 76: val_main_output_dice_coef did not improve from 0.81816
#
# Epoch 76 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9951
#   main_output_dice_coef: 0.8799
#   main_output_loss: 0.0122
#   main_output_mean_io_u_1: 0.7768
#   main_output_precision: 0.9953
#   main_output_sensitivity: 0.9949
#   main_output_specificity: 0.9984
# Validation:
#   val_main_output_accuracy: 0.9885
#   val_main_output_dice_coef: 0.8159
#   val_main_output_loss: 0.0479
#   val_main_output_mean_io_u_1: 0.8028
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9963
#
# ...
#   main_output_mean_io_u_1: 0.9084
#   main_output_precision: 0.9969
#   main_output_sensitivity: 0.9967
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8329
#   val_main_output_loss: 0.0613
#   val_main_output_mean_io_u_1: 0.9126
#   val_main_output_precision: 0.9887
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9962
#
# Epoch 175: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 175 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9967
#   main_output_dice_coef: 0.9164
#   main_output_loss: 0.0079
#   main_output_mean_io_u_1: 0.9080
#   main_output_precision: 0.9968
#   main_output_sensitivity: 0.9967
#   main_output_specificity: 0.9989
# Validation:
#   val_main_output_accuracy: 0.9889
#   val_main_output_dice_coef: 0.8342
#   val_main_output_loss: 0.0607
#   val_main_output_mean_io_u_1: 0.8990
#   val_main_output_precision: 0.9891
#   val_main_output_sensitivity: 0.9888
#   val_main_output_specificity: 0.9964
#
# Epoch 176: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 176 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9968
#   main_output_dice_coef: 0.9175
#   main_output_loss: 0.0077
#   main_output_mean_io_u_1: 0.9140
#   main_output_precision: 0.9969
#   main_output_sensitivity: 0.9967
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9888
#   val_main_output_dice_coef: 0.8319
#   val_main_output_loss: 0.0597
#   val_main_output_mean_io_u_1: 0.8961
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9886
#   val_main_output_specificity: 0.9963
#
# Epoch 177: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 177 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9194
#   main_output_loss: 0.0075
#   main_output_mean_io_u_1: 0.9191
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9882
#   val_main_output_dice_coef: 0.8266
#   val_main_output_loss: 0.0621
#   val_main_output_mean_io_u_1: 0.9111
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9961
#
# Epoch 178: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 178 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9195
#   main_output_loss: 0.0075
#   main_output_mean_io_u_1: 0.9124
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9890
#   val_main_output_dice_coef: 0.8331
#   val_main_output_loss: 0.0583
#   val_main_output_mean_io_u_1: 0.9037
#   val_main_output_precision: 0.9892
#   val_main_output_sensitivity: 0.9889
#   val_main_output_specificity: 0.9964
#
# Epoch 179: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 179 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9188
#   main_output_loss: 0.0076
#   main_output_mean_io_u_1: 0.9095
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9888
#   val_main_output_dice_coef: 0.8276
#   val_main_output_loss: 0.0613
#   val_main_output_mean_io_u_1: 0.9161
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9887
#   val_main_output_specificity: 0.9963
#
# Epoch 180: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 180 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9968
#   main_output_dice_coef: 0.9197
#   main_output_loss: 0.0077
#   main_output_mean_io_u_1: 0.9075
#   main_output_precision: 0.9969
#   main_output_sensitivity: 0.9967
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9885
#   val_main_output_dice_coef: 0.8203
#   val_main_output_loss: 0.0608
#   val_main_output_mean_io_u_1: 0.9212
#   val_main_output_precision: 0.9887
#   val_main_output_sensitivity: 0.9884
#   val_main_output_specificity: 0.9962
#
# Epoch 181: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 181 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9197
#   main_output_loss: 0.0076
#   main_output_mean_io_u_1: 0.9131
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8226
#   val_main_output_loss: 0.0615
#   val_main_output_mean_io_u_1: 0.9241
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9962
#
# Epoch 182: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 182 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9186
#   main_output_loss: 0.0076
#   main_output_mean_io_u_1: 0.9153
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9888
#   val_main_output_dice_coef: 0.8328
#   val_main_output_loss: 0.0626
#   val_main_output_mean_io_u_1: 0.9252
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9887
#   val_main_output_specificity: 0.9963
#
# Epoch 183: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 183 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9202
#   main_output_loss: 0.0075
#   main_output_mean_io_u_1: 0.9216
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8348
#   val_main_output_loss: 0.0617
#   val_main_output_mean_io_u_1: 0.9011
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9962
#
# Epoch 184: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 184 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9187
#   main_output_loss: 0.0075
#   main_output_mean_io_u_1: 0.9192
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8331
#   val_main_output_loss: 0.0634
#   val_main_output_mean_io_u_1: 0.9001
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9882
#   val_main_output_specificity: 0.9962
#
# Epoch 185: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 185 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9200
#   main_output_loss: 0.0073
#   main_output_mean_io_u_1: 0.9182
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9879
#   val_main_output_dice_coef: 0.8282
#   val_main_output_loss: 0.0684
#   val_main_output_mean_io_u_1: 0.9198
#   val_main_output_precision: 0.9881
#   val_main_output_sensitivity: 0.9878
#   val_main_output_specificity: 0.9960
#
# Epoch 186: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 186 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9217
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9230
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9970
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8322
#   val_main_output_loss: 0.0622
#   val_main_output_mean_io_u_1: 0.8950
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9962
#
# Epoch 187: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 187 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9202
#   main_output_loss: 0.0074
#   main_output_mean_io_u_1: 0.9216
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9878
#   val_main_output_dice_coef: 0.8312
#   val_main_output_loss: 0.0652
#   val_main_output_mean_io_u_1: 0.8899
#   val_main_output_precision: 0.9880
#   val_main_output_sensitivity: 0.9877
#   val_main_output_specificity: 0.9960
#
# Epoch 188: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 188 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9968
#   main_output_dice_coef: 0.9190
#   main_output_loss: 0.0078
#   main_output_mean_io_u_1: 0.9105
#   main_output_precision: 0.9969
#   main_output_sensitivity: 0.9967
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9883
#   val_main_output_dice_coef: 0.8261
#   val_main_output_loss: 0.0651
#   val_main_output_mean_io_u_1: 0.9228
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9962
#
# Epoch 189: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 189 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9968
#   main_output_dice_coef: 0.9192
#   main_output_loss: 0.0077
#   main_output_mean_io_u_1: 0.9136
#   main_output_precision: 0.9969
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9884
#   val_main_output_dice_coef: 0.8179
#   val_main_output_loss: 0.0627
#   val_main_output_mean_io_u_1: 0.9235
#   val_main_output_precision: 0.9886
#   val_main_output_sensitivity: 0.9883
#   val_main_output_specificity: 0.9962
#
# Epoch 190: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 190 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9202
#   main_output_loss: 0.0073
#   main_output_mean_io_u_1: 0.9203
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9880
#   val_main_output_dice_coef: 0.8251
#   val_main_output_loss: 0.0621
#   val_main_output_mean_io_u_1: 0.8892
#   val_main_output_precision: 0.9882
#   val_main_output_sensitivity: 0.9879
#   val_main_output_specificity: 0.9961
#
# Epoch 191: val_main_output_dice_coef did not improve from 0.83590
#
# Epoch 191 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9971
#   main_output_dice_coef: 0.9228
#   main_output_loss: 0.0070
#   main_output_mean_io_u_1: 0.9221
#   main_output_precision: 0.9972
#   main_output_sensitivity: 0.9971
#   main_output_specificity: 0.9991
# Validation:
#   val_main_output_accuracy: 0.9888
#   val_main_output_dice_coef: 0.8343
#   val_main_output_loss: 0.0650
#   val_main_output_mean_io_u_1: 0.9066
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9887
#   val_main_output_specificity: 0.9963
#
# Epoch 192: val_main_output_dice_coef improved from 0.83590 to 0.83745, saving model to Downloads/archive_2/model_segmentation\u2net_3d__attn_200epoch.hdf5
#
# Epoch 192 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9971
#   main_output_dice_coef: 0.9226
#   main_output_loss: 0.0070
#   main_output_mean_io_u_1: 0.9202
#   main_output_precision: 0.9972
#   main_output_sensitivity: 0.9971
#   main_output_specificity: 0.9991
# Validation:
#   val_main_output_accuracy: 0.9887
#   val_main_output_dice_coef: 0.8374
#   val_main_output_loss: 0.0664
#   val_main_output_mean_io_u_1: 0.9179
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9885
#   val_main_output_specificity: 0.9963
#
# Epoch 193: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 193 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9217
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9203
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9887
#   val_main_output_dice_coef: 0.8352
#   val_main_output_loss: 0.0670
#   val_main_output_mean_io_u_1: 0.9261
#   val_main_output_precision: 0.9889
#   val_main_output_sensitivity: 0.9886
#   val_main_output_specificity: 0.9963
#
# Epoch 194: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 194 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9207
#   main_output_loss: 0.0074
#   main_output_mean_io_u_1: 0.9229
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9882
#   val_main_output_dice_coef: 0.8310
#   val_main_output_loss: 0.0650
#   val_main_output_mean_io_u_1: 0.8938
#   val_main_output_precision: 0.9885
#   val_main_output_sensitivity: 0.9881
#   val_main_output_specificity: 0.9962
#
# Epoch 195: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 195 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9969
#   main_output_dice_coef: 0.9210
#   main_output_loss: 0.0075
#   main_output_mean_io_u_1: 0.9170
#   main_output_precision: 0.9970
#   main_output_sensitivity: 0.9968
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9885
#   val_main_output_dice_coef: 0.8329
#   val_main_output_loss: 0.0630
#   val_main_output_mean_io_u_1: 0.9181
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9884
#   val_main_output_specificity: 0.9963
#
# Epoch 196: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 196 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9226
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9198
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9970
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9887
#   val_main_output_dice_coef: 0.8253
#   val_main_output_loss: 0.0610
#   val_main_output_mean_io_u_1: 0.9196
#   val_main_output_precision: 0.9889
#   val_main_output_sensitivity: 0.9885
#   val_main_output_specificity: 0.9963
#
# Epoch 197: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 197 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9236
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9172
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9970
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9888
#   val_main_output_dice_coef: 0.8336
#   val_main_output_loss: 0.0639
#   val_main_output_mean_io_u_1: 0.9221
#   val_main_output_precision: 0.9890
#   val_main_output_sensitivity: 0.9887
#   val_main_output_specificity: 0.9963
#
# Epoch 198: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 198 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9235
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9143
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9970
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9886
#   val_main_output_dice_coef: 0.8352
#   val_main_output_loss: 0.0673
#   val_main_output_mean_io_u_1: 0.9241
#   val_main_output_precision: 0.9888
#   val_main_output_sensitivity: 0.9885
#   val_main_output_specificity: 0.9963
#
# Epoch 199: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 199 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9251
#   main_output_loss: 0.0072
#   main_output_mean_io_u_1: 0.9207
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9880
#   val_main_output_dice_coef: 0.8350
#   val_main_output_loss: 0.0706
#   val_main_output_mean_io_u_1: 0.9363
#   val_main_output_precision: 0.9882
#   val_main_output_sensitivity: 0.9879
#   val_main_output_specificity: 0.9961
#
# Epoch 200: val_main_output_dice_coef did not improve from 0.83745
#
# Epoch 200 - Main Output Metrics:
# Train:
#   main_output_accuracy: 0.9970
#   main_output_dice_coef: 0.9220
#   main_output_loss: 0.0073
#   main_output_mean_io_u_1: 0.9236
#   main_output_precision: 0.9971
#   main_output_sensitivity: 0.9969
#   main_output_specificity: 0.9990
# Validation:
#   val_main_output_accuracy: 0.9881
#   val_main_output_dice_coef: 0.8331
#   val_main_output_loss: 0.0631
#   val_main_output_mean_io_u_1: 0.8788
#   val_main_output_precision: 0.9884
#   val_main_output_sensitivity: 0.9880
#   val_main_output_specificity: 0.9961

# %%
loss = history.history['main_output_loss']
val_loss = history.history['val_main_output_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
acc = history.history['main_output_accuracy']
val_acc = history.history['val_main_output_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
dice = history.history['main_output_dice_coef']
val_dice = history.history['val_main_output_dice_coef']

epochs = range(1, len(dice) + 1)
plt.plot(epochs, dice, 'y', label='Training Dice Coefficient')
plt.plot(epochs, val_dice, 'r', label='Validation Dice Coefficient')
plt.title('Training and Validation Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Dice Coefficient')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
precision = history.history['main_output_precision']
val_precision = history.history['val_main_output_precision']
epochs = range(1, len(precision) + 1)
plt.plot(epochs, precision, 'y', label='Training Precision')
plt.plot(epochs, val_precision, 'r', label='Validation Precision')
plt.title('Training and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
sensitivity = history.history['main_output_sensitivity']
val_sensitivity = history.history['val_main_output_sensitivity']
epochs = range(1, len(sensitivity) + 1)
plt.plot(epochs, sensitivity, 'y', label='Training Sensitivity')
plt.plot(epochs, val_sensitivity, 'r', label='Validation Sensitivity')
plt.title('Training and Validation Sensitivity')
plt.xlabel('Epochs')
plt.ylabel('Sensitivity')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
specificity = history.history['main_output_specificity']
val_specificity = history.history['val_main_output_specificity']
epochs = range(1, len(specificity) + 1)
plt.plot(epochs, specificity, 'y', label='Training Specificity')
plt.plot(epochs, val_specificity, 'r', label='Validation Specificity')
plt.title('Training and Validation Specificity')
plt.xlabel('Epochs')
plt.ylabel('Specificity')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
mean_iou = history.history['main_output_mean_io_u_1']
val_mean_iou = history.history['val_main_output_mean_io_u_1']
epochs = range(1, len(mean_iou) + 1)
plt.plot(epochs, mean_iou, 'y', label='Training Mean IoU')
plt.plot(epochs, val_mean_iou, 'r', label='Validation Mean IoU')
plt.title('Training and Validation Mean IoU')
plt.xlabel('Epochs')
plt.ylabel('Mean IoU')
plt.ylim(0, 1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
loss = history.history['main_output_loss']
val_loss = history.history['val_main_output_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %%
acc = history.history['main_output_accuracy']
val_acc = history.history['val_main_output_accuracy']

plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
dice = history.history['main_output_dice_coef']
val_dice = history.history['val_main_output_dice_coef']

epochs = range(1, len(dice) + 1)
plt.plot(epochs, dice, 'y', label='Training Dice Coefficient')
plt.plot(epochs, val_dice, 'r', label='Validation Dice Coefficient')
plt.title('Training and Validation Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.tight_layout()
plt.show()

# %%
precision = history.history['main_output_precision']
val_precision = history.history['val_main_output_precision']
epochs = range(1, len(precision) + 1)
plt.plot(epochs, precision, 'y', label='Training Precision')
plt.plot(epochs, val_precision, 'r', label='Validation Precision')
plt.title('Training and Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.legend()
plt.tight_layout()
plt.show()

# %%
specificity = history.history['main_output_specificity']
val_specificity = history.history['val_main_output_specificity']
epochs = range(1, len(specificity) + 1)
plt.plot(epochs, specificity, 'y', label='Training Specificity')
plt.plot(epochs, val_specificity, 'r', label='Validation Specificity')
plt.title('Training and Validation Specificity')
plt.xlabel('Epochs')
plt.ylabel('Specificity')

plt.legend()
plt.tight_layout()
plt.show()

# %%
mean_iou = history.history['main_output_mean_io_u']
val_mean_iou = history.history['val_main_output_mean_io_u']
epochs = range(1, len(mean_iou) + 1)
plt.plot(epochs, mean_iou, 'y', label='Training Mean IoU')
plt.plot(epochs, val_mean_iou, 'r', label='Validation Mean IoU')
plt.title('Training and Validation Mean IoU')
plt.xlabel('Epochs')
plt.ylabel('Mean IoU')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sensitivity = history.history['main_output_sensitivity']
val_sensitivity = history.history['val_main_output_sensitivity']
epochs = range(1, len(sensitivity) + 1)
plt.plot(epochs, sensitivity, 'y', label='Training Sensitivity')
plt.plot(epochs, val_sensitivity, 'r', label='Validation Sensitivity')
plt.title('Training and Validation Sensitivity')
plt.xlabel('Epochs')
plt.ylabel('Sensitivity')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User

# %%
#model.save('Downloads/archive_2/model_segmentation/brats_2021_200epoch_residual2.hdf5')

# %%
from keras.models import load_model
my_model = load_model('Downloads/archive_2/model_segmentation/u2net_3d_150epoch.hdf5', compile = False)

# %%
#Prediction on a few test images, one at a time

img_num = 221

test_img = np.load("Downloads/archive_2/input/output_data/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("Downloads/archive_2/input/output_data/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
#test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]
test_prediction_argmax = np.argmax(test_prediction, axis=-1)[0]  # shape: (H, W, D)
# Out:
# 1/1 [==============================] - 0s 157ms/step

# %%
test_img_input.shape
# Out:
# (1, 128, 128, 64, 3)

# %%
test_prediction_argmax.shape
# Out:
# (1, 128, 128, 64)

# %%
test_prediction_argmax = test_prediction_argmax[0]  # shape: (128, 128, 64)

# %%
test_prediction_argmax.shape
# Out:
# (128, 128, 64)

# %%
#Plot individual slices from test predictions for verification
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 12
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()

# %%
print("Prediction shape:", test_prediction_argmax.shape)
print("Unique values in prediction slice:", np.unique(test_prediction_argmax[:, :, n_slice]))
# Out:
# Prediction shape: (128, 128, 64)
# Unique values in prediction slice: [0 1 2 3]

# %%
#Prediction on a few test images, one at a time

img_num = 329

test_img = np.load("Downloads/archive_2/input/output_data/val/images/image_"+str(img_num)+".npy")

test_mask = np.load("Downloads/archive_2/input/output_data/val/masks/mask_"+str(img_num)+".npy")
test_mask_argmax=np.argmax(test_mask, axis=3)

test_img_input = np.expand_dims(test_img, axis=0)
test_prediction = my_model.predict(test_img_input)
#test_prediction_argmax=np.argmax(test_prediction, axis=4)[0,:,:,:]
test_prediction_argmax = np.argmax(test_prediction, axis=-1)[0] 
test_prediction_argmax = test_prediction_argmax[0]
# Out:
# 1/1 [==============================] - 0s 164ms/step

# %%
from matplotlib import pyplot as plt
import random

#n_slice=random.randint(0, test_prediction_argmax.shape[2])
n_slice = 1
plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[:,:,n_slice,1], cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_argmax[:,:,n_slice])
plt.subplot(233)
#plt.title('Prediction on test image')
plt.imshow(test_prediction_argmax[:,:, n_slice])
plt.show()
